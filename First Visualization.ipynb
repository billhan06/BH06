# %%
import random

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
import csv

# %%
def loadList(fileName):
  with open(fileName, newline='') as f:
    reader = csv.reader(f)
    dataList = list(reader)
  return dataList

# %%
rawData = loadList('Book1.csv')
rawData
# Out:
# [['Afghanistan',
#   '2193',
#   '1841',
#   '1739',
#   '1208',
#   '877',
#   '1244',
#   '1130',
#   '1039',
#   '967',
#   '894',
#   '817',
#   '738',
#   '1159',
#   '1176',
#   '1126',
#   '1198',
#   '1244',
#   '1361',
#   '1358',
#   '1498',
#   '1675',
#   '1625',
#   '1776',
#   '1814',
#   '1796',
#   '1783',
#   '1766',
#   '1767',
#   '1746',
#   ''],
#  ['Albania',
#   '4415',
#   '3138',
#   '2857',
#   '3261',
#   '3600',
#   '4168',
#   '4594',
#   '4112',
#   '4530',
#   '5141',
#   '5562',
#   '6093',
#   '6358',
#   '6760',
#   '7147',
#   '7557',
#   '8125',
#   '8671',
#   '9199',
#   '9376',
#   '9828',
#   '10210',
#   '10293',
#   '10669',
#   '10797',
#   '11098',
#   '11534',
#   '11831',
#   '12300',
#   ''],
#  ['Algeria',
#   '9989',
#   '9457',
#   '9462',
#   '9171',
#   '8847',
#   '8904',
#   '9069',
#   '9099',
#   '9502',
#   '9596',
#   '9700',
#   '10130',
#   '10447',
#   '11068',
#   '11305',
#   '11595',
#   '11734',
#   '12419',
#   '12640',
#   '12602',
#   '12946',
#   '12908',
#   '12910',
#   '12946',
#   '13169',
#   '13330',
#   '13832',
#   '13656',
#   '13639',
#   ''],
#  ['Andorra',
#   '49062',
#   '48391',
#   '47002',
#   '44928',
#   '44747',
#   '45136',
#   '46861',
#   '51136',
#   '52922',
#   '54896',
#   '44215',
#   '44886',
#   '45943',
#   '49328',
#   '50968',
#   '52917',
#   '53867',
#   '52786',
#   '47574',
#   '45492',
#   '43061',
#   '41402',
#   '41386',
#   '42376',
#   '44197',
#   '45260',
#   '46553',
#   '47550',
#   '48641',
#   ' a'],
#  ['Angola',
#   '4139',
#   '4528',
#   '1737',
#   '1704',
#   '1304',
#   '2858',
#   '2826',
#   '3335',
#   '3269',
#   '2952',
#   '3092',
#   '3268',
#   '3904',
#   '3924',
#   '4130',
#   '4516',
#   '4751',
#   '5327',
#   '5437',
#   '5863',
#   '5818',
#   '5796',
#   '6128',
#   '6294',
#   '6484',
#   '6440',
#   '6051',
#   '5950',
#   '5555',
#   ''],
#  ['Antigua and Barbuda',
#   '15749',
#   '16439',
#   '16475',
#   '17300',
#   '18021',
#   '16842',
#   '17665',
#   '18401',
#   '18943',
#   '19230',
#   '19676',
#   '18853',
#   '18396',
#   '19378',
#   '20145',
#   '21315',
#   '23686',
#   '25479',
#   '24945',
#   '21655',
#   '20096',
#   '19264',
#   '19529',
#   '19276',
#   '19780',
#   '20279',
#   '20909',
#   '21349',
#   '22201',
#   ''],
#  ['Argentina',
#   '10932',
#   '11902',
#   '12816',
#   '13774',
#   '14371',
#   '13742',
#   '14297',
#   '15263',
#   '15619',
#   '14903',
#   '14617',
#   '13791',
#   '11841',
#   '12910',
#   '12911',
#   '13886',
#   '16185',
#   '17586',
#   '18137',
#   '16791',
#   '18279',
#   '19251',
#   '18940',
#   '19228',
#   '18562',
#   '18901',
#   '18249',
#   '18462',
#   '77611',
#   ''],
#  ['Armenia',
#   '3600',
#   '3327',
#   '1649',
#   '1691',
#   '1988',
#   '2167',
#   '2403',
#   '2595',
#   '2725',
#   '2827',
#   '3006',
#   '3325',
#   '3814',
#   '4358',
#   '4822',
#   '5600',
#   '6426',
#   '7425',
#   '8045',
#   '6811',
#   '7061',
#   '7269',
#   '7793',
#   '8169',
#   '8301',
#   '8482',
#   '8310',
#   '9064',
#   '9277',
#   ''],
#  ['Australia',
#   '27679',
#   '27203',
#   '27159',
#   '28112',
#   '28942',
#   '29524',
#   '30234',
#   '31130',
#   '32284',
#   '33555',
#   '34533',
#   '34748',
#   '35729',
#   '36308',
#   '37314',
#   '37669',
#   '38060',
#   '39025',
#   '39780',
#   '39939',
#   '39982',
#   '40281',
#   '41566',
#   '42201',
#   '42594',
#   '43246',
#   '43653',
#   '43756',
#   '44097',
#   ''],
#  ['Austria',
#   '31587',
#   '32192',
#   '32442',
#   '32368',
#   '32951',
#   '33659',
#   '34520',
#   '35057',
#   '36218',
#   '37059',
#   '38502',
#   '38644',
#   '39405',
#   '39716',
#   '40597',
#   '41196',
#   '42600',
#   '43896',
#   '44815',
#   '42640',
#   '43700',
#   '44603',
#   '44597',
#   '44420',
#   '44306',
#   '43822',
#   '44621',
#   '45375',
#   '46231',
#   ''],
#  ['Azerbaijan',
#   '8710',
#   '8514',
#   '6489',
#   '4975',
#   '3940',
#   '3430',
#   '3415',
#   '3606',
#   '3928',
#   '4162',
#   '4426',
#   '4816',
#   '5209',
#   '5689',
#   '6028',
#   '7184',
#   '9329',
#   '11155',
#   '12858',
#   '14628',
#   '15425',
#   '14676',
#   '15056',
#   '15846',
#   '16444',
#   '16259',
#   '15146',
#   '15312',
#   '15240',
#   ''],
#  ['Bahamas',
#   '29469',
#   '27683',
#   '26858',
#   '26089',
#   '26432',
#   '31405',
#   '34558',
#   '28504',
#   '29326',
#   '31477',
#   '32303',
#   '32448',
#   '32837',
#   '31999',
#   '31779',
#   '32139',
#   '32259',
#   '32076',
#   '31323',
#   '29258',
#   '29085',
#   '28953',
#   '29753',
#   '29372',
#   '28661',
#   '28763',
#   '27791',
#   '28067',
#   '28395',
#   ''],
#  ['Bahrain',
#   '29850',
#   '40166',
#   '40370',
#   '42512',
#   '41106',
#   '43105',
#   '43978',
#   '42635',
#   '43808',
#   '43385',
#   '44495',
#   '43081',
#   '41877',
#   '42112',
#   '42161',
#   '42760',
#   '42375',
#   '42696',
#   '41154',
#   '37214',
#   '37246',
#   '35445',
#   '36153',
#   '37643',
#   '36619',
#   '42125',
#   '41499',
#   '41645',
#   '40399',
#   ''],
#  ['Bangladesh',
#   '1358',
#   '1374',
#   '1420',
#   '1458',
#   '1490',
#   '1531',
#   '1559',
#   '1598',
#   '1646',
#   '1691',
#   '1750',
#   '1801',
#   '1852',
#   '1907',
#   '1982',
#   '2082',
#   '2218',
#   '2362',
#   '2501',
#   '2603',
#   '2723',
#   '2861',
#   '3025',
#   '3158',
#   '3270',
#   '3439',
#   '3620',
#   '3792',
#   '4057',
#   ''],
#  ['Barbados',
#   '13806',
#   '13255',
#   '12347',
#   '12389',
#   '12786',
#   '12930',
#   '13344',
#   '13992',
#   '14457',
#   '14372',
#   '14922',
#   '14445',
#   '14476',
#   '14688',
#   '14962',
#   '15311',
#   '15834',
#   '16405',
#   '16160',
#   '15601',
#   '15874',
#   '15281',
#   '15733',
#   '15617',
#   '15580',
#   '15635',
#   '15881',
#   '16033',
#   '15912',
#   ''],
#  ['Belarus',
#   '8360',
#   '8255',
#   '7447',
#   '6865',
#   '6062',
#   '5443',
#   '5620',
#   '6271',
#   '6829',
#   '7103',
#   '7549',
#   '7943',
#   '8410',
#   '9088',
#   '10195',
#   '11237',
#   '12387',
#   '13446',
#   '14809',
#   '14764',
#   '15978',
#   '16815',
#   '17069',
#   '17006',
#   '17370',
#   '16450',
#   '15997',
#   '16542',
#   '17039',
#   ''],
#  ['Belgium',
#   '30781',
#   '31342',
#   '31688',
#   '31564',
#   '32720',
#   '33350',
#   '33854',
#   '35061',
#   '35678',
#   '36822',
#   '38152',
#   '38062',
#   '38510',
#   '38714',
#   '39735',
#   '40281',
#   '41091',
#   '42179',
#   '42589',
#   '40410',
#   '42385',
#   '41700',
#   '42125',
#   '41688',
#   '41632',
#   '41598',
#   '42260',
#   '43300',
#   '43821',
#   ''],
#  ['Belize',
#   '4977',
#   '5441',
#   '5953',
#   '6195',
#   '6004',
#   '5932',
#   '5802',
#   '5834',
#   '5755',
#   '5984',
#   '6476',
#   '6502',
#   '6675',
#   '7000',
#   '7000',
#   '7054',
#   '7188',
#   '6916',
#   '7002',
#   '7266',
#   '7109',
#   '7318',
#   '7274',
#   '7185',
#   '7235',
#   '7523',
#   '7272',
#   '7059',
#   '7136',
#   ''],
#  ['Benin',
#   '1432',
#   '1449',
#   '1409',
#   '1470',
#   '1443',
#   '1482',
#   '1500',
#   '1549',
#   '1577',
#   '1615',
#   '1659',
#   '1694',
#   '1713',
#   '1718',
#   '1743',
#   '1730',
#   '1743',
#   '1791',
#   '1838',
#   '1823',
#   '1805',
#   '1817',
#   '1840',
#   '1919',
#   '1988',
#   '1971',
#   '2001',
#   '2055',
#   '2135',
#   ''],
#  ['Bhutan',
#   '2207',
#   '2126',
#   '2160',
#   '2237',
#   '2423',
#   '2447',
#   '2584',
#   '2749',
#   '2648',
#   '2723',
#   '3429',
#   '3635',
#   '3887',
#   '4075',
#   '4239',
#   '4511',
#   '4807',
#   '5552',
#   '5678',
#   '5917',
#   '6435',
#   '6814',
#   '6961',
#   '7096',
#   '7410',
#   '7807',
#   '8202',
#   '8472',
#   '8609',
#   ''],
#  ['Bolivia (Plurinational State of)',
#   '3530',
#   '3662',
#   '3688',
#   '3764',
#   '3879',
#   '3976',
#   '4075',
#   '4205',
#   '4354',
#   '4268',
#   '4279',
#   '4273',
#   '4296',
#   '4280',
#   '4344',
#   '4476',
#   '4626',
#   '4743',
#   '4975',
#   '5028',
#   '5111',
#   '5257',
#   '5360',
#   '5627',
#   '5932',
#   '6260',
#   '6535',
#   '6640',
#   '6849',
#   ''],
#  ['Bosnia and Herzegovina',
#   '1343',
#   '1243',
#   '1199',
#   '1216',
#   '1281',
#   '1594',
#   '3239',
#   '4469',
#   '6595',
#   '6962',
#   '7024',
#   '7235',
#   '7491',
#   '7692',
#   '8035',
#   '8686',
#   '9057',
#   '9599',
#   '10214',
#   '9969',
#   '9923',
#   '10057',
#   '10127',
#   '10603',
#   '10858',
#   '11351',
#   '11810',
#   '12220',
#   '12690',
#   ''],
#  ['Botswana',
#   '8270',
#   '8989',
#   '9082',
#   '9371',
#   '8495',
#   '9249',
#   '9131',
#   '9897',
#   '10223',
#   '10225',
#   '10056',
#   '10283',
#   '9663',
#   '10319',
#   '10266',
#   '10725',
#   '11468',
#   '12293',
#   '12834',
#   '12128',
#   '12673',
#   '14036',
#   '14576',
#   '15326',
#   '15817',
#   '15414',
#   '15353',
#   '15596',
#   '15951',
#   ''],
#  ['Brazil',
#   '10082',
#   '10089',
#   '9905',
#   '10142',
#   '10368',
#   '10901',
#   '10835',
#   '10973',
#   '10707',
#   '10518',
#   '11090',
#   '11051',
#   '11223',
#   '11232',
#   '11762',
#   '12007',
#   '12394',
#   '13061',
#   '13547',
#   '13424',
#   '14194',
#   '14670',
#   '14892',
#   '15351',
#   '15177',
#   '14490',
#   '13907',
#   '13975',
#   '14068',
#   ''],
#  ['Brunei Darussalam',
#   '85147',
#   '85355',
#   '86908',
#   '84763',
#   '85081',
#   '86600',
#   '86896',
#   '83605',
#   '81266',
#   '81932',
#   '82508',
#   '83059',
#   '84596',
#   '85449',
#   '84413',
#   '83421',
#   '85879',
#   '85361',
#   '82688',
#   '80279',
#   '80394',
#   '80283',
#   '80203',
#   '78725',
#   '76778',
#   '79110',
#   '77492',
#   '77188',
#   '76389',
#   ' b'],
#  ['Bulgaria',
#   '8518',
#   '7743',
#   '7940',
#   '7880',
#   '8035',
#   '8271',
#   '8307',
#   '8282',
#   '8964',
#   '8293',
#   '8642',
#   '9372',
#   '10327',
#   '10901',
#   '11643',
#   '12461',
#   '13065',
#   '13447',
#   '14811',
#   '14715',
#   '14975',
#   '15184',
#   '15570',
#   '15596',
#   '16193',
#   '16662',
#   '17757',
#   '18874',
#   '19646',
#   ''],
#  ['Burkina Faso',
#   '845',
#   '897',
#   '875',
#   '879',
#   '865',
#   '893',
#   '971',
#   '1000',
#   '1044',
#   '1089',
#   '1069',
#   '1109',
#   '1127',
#   '1180',
#   '1197',
#   '1266',
#   '1310',
#   '1340',
#   '1395',
#   '1393',
#   '1389',
#   '1418',
#   '1494',
#   '1538',
#   '1538',
#   '1545',
#   '1582',
#   '1640',
#   '1705',
#   ''],
#  ['Burundi',
#   '1014',
#   '1045',
#   '1030',
#   '949',
#   '895',
#   '812',
#   '735',
#   '719',
#   '748',
#   '727',
#   '729',
#   '707',
#   '717',
#   '683',
#   '689',
#   '682',
#   '702',
#   '704',
#   '716',
#   '714',
#   '730',
#   '733',
#   '746',
#   '761',
#   '767',
#   '715',
#   '689',
#   '670',
#   '660',
#   ''],
#  ['Cabo Verde',
#   '1688',
#   '1665',
#   '1797',
#   '1896',
#   '2191',
#   '2428',
#   '2631',
#   '2864',
#   '3148',
#   '3420',
#   '3795',
#   '3872',
#   '3956',
#   '4082',
#   '4424',
#   '4593',
#   '4865',
#   '5648',
#   '5918',
#   '5776',
#   '5680',
#   '5863',
#   '5832',
#   '5850',
#   '5721',
#   '5782',
#   '5989',
#   '6164',
#   '6513',
#   ''],
#  ['Cambodia',
#   '1381',
#   '1428',
#   '1480',
#   '1502',
#   '915',
#   '1084',
#   '1106',
#   '1133',
#   '1148',
#   '1250',
#   '1338',
#   '1414',
#   '1466',
#   '1573',
#   '1704',
#   '1888',
#   '2062',
#   '2255',
#   '2354',
#   '2313',
#   '2410',
#   '2534',
#   '2657',
#   '2836',
#   '2959',
#   '3085',
#   '3248',
#   '3418',
#   '3597',
#   ''],
#  ['Cameroon',
#   '2889',
#   '2642',
#   '2517',
#   '2255',
#   '2226',
#   '2237',
#   '2271',
#   '2324',
#   '2396',
#   '2440',
#   '2413',
#   '2432',
#   '2492',
#   '2599',
#   '2735',
#   '2704',
#   '2762',
#   '2792',
#   '2830',
#   '2847',
#   '2848',
#   '2884',
#   '2919',
#   '2982',
#   '3108',
#   '3178',
#   '3229',
#   '3250',
#   '3291',
#   ''],
#  ['Canada',
#   '30384',
#   '29469',
#   '29310',
#   '29820',
#   '30767',
#   '31302',
#   '31510',
#   '32608',
#   '33524',
#   '34963',
#   '36681',
#   '36862',
#   '37676',
#   '38021',
#   '38934',
#   '39837',
#   '40655',
#   '41136',
#   '41093',
#   '39347',
#   '39996',
#   '40880',
#   '41199',
#   '41818',
#   '42546',
#   '42567',
#   '42691',
#   '43496',
#   '43602',
#   ''],
#  ['Central African Republic',
#   '968',
#   '942',
#   '858',
#   '833',
#   '841',
#   '882',
#   '823',
#   '849',
#   '865',
#   '885',
#   '839',
#   '862',
#   '874',
#   '815',
#   '840',
#   '834',
#   '856',
#   '880',
#   '878',
#   '947',
#   '987',
#   '1020',
#   '1068',
#   '681',
#   '679',
#   '706',
#   '732',
#   '756',
#   '777',
#   ''],
#  ['Chad',
#   '1096',
#   '1165',
#   '1224',
#   '962',
#   '1055',
#   '1036',
#   '1021',
#   '1037',
#   '1084',
#   '1038',
#   '978',
#   '1050',
#   '1074',
#   '976',
#   '1334',
#   '1514',
#   '1453',
#   '1493',
#   '1444',
#   '1669',
#   '1850',
#   '1805',
#   '1902',
#   '1899',
#   '1971',
#   '1999',
#   '1836',
#   '1736',
#   '1716',
#   ''],
#  ['Chile',
#   '8611',
#   '9141',
#   '10081',
#   '10638',
#   '10890',
#   '11736',
#   '12421',
#   '13182',
#   '13675',
#   '13379',
#   '13844',
#   '14168',
#   '14383',
#   '14514',
#   '15033',
#   '15611',
#   '15642',
#   '16410',
#   '17598',
#   '17299',
#   '17989',
#   '19112',
#   '20247',
#   '20960',
#   '21300',
#   '21653',
#   '21776',
#   '21415',
#   '21972',
#   ''],
#  ['China',
#   '1530',
#   '1649',
#   '1857',
#   '2085',
#   '2331',
#   '2522',
#   '2747',
#   '2978',
#   '3167',
#   '3389',
#   '3651',
#   '3918',
#   '4263',
#   '4678',
#   '5137',
#   '5665',
#   '6381',
#   '7281',
#   '7974',
#   '8613',
#   '9458',
#   '10259',
#   '11090',
#   '11823',
#   '12742',
#   '13485',
#   '14311',
#   '15212',
#   '16127',
#   ''],
#  ['Colombia',
#   '7392',
#   '7434',
#   '7617',
#   '7945',
#   '8331',
#   '8613',
#   '8601',
#   '8737',
#   '8683',
#   '8193',
#   '8254',
#   '8239',
#   '8300',
#   '8439',
#   '8756',
#   '9131',
#   '9612',
#   '10100',
#   '10254',
#   '10305',
#   '10567',
#   '11151',
#   '11538',
#   '11996',
#   '12513',
#   '12951',
#   '13087',
#   '12963',
#   '12896',
#   ''],
#  ['Comoros',
#   '2576',
#   '2368',
#   '2520',
#   '2510',
#   '2305',
#   '2325',
#   '2229',
#   '2257',
#   '2222',
#   '2211',
#   '2391',
#   '2389',
#   '2378',
#   '2369',
#   '2355',
#   '2367',
#   '2374',
#   '2345',
#   '2372',
#   '2391',
#   '2424',
#   '2463',
#   '2479',
#   '2534',
#   '2529',
#   '2504',
#   '2504',
#   '2515',
#   '2426',
#   ''],
#  ['Congo',
#   '5976',
#   '6060',
#   '6307',
#   '5676',
#   '5506',
#   '4001',
#   '4024',
#   '4484',
#   '5178',
#   '4034',
#   '3564',
#   '3998',
#   '4054',
#   '3940',
#   '3613',
#   '2975',
#   '2674',
#   '3131',
#   '3614',
#   '4068',
#   '4051',
#   '3976',
#   '4742',
#   '5108',
#   '5942',
#   '7631',
#   '6765',
#   '6068',
#   '5804',
#   ''],
#  ['Congo (Democratic Republic of the)',
#   '2054',
#   '1684',
#   '1550',
#   '1330',
#   '729',
#   '696',
#   '725',
#   '664',
#   '642',
#   '579',
#   '565',
#   '522',
#   '531',
#   '548',
#   '564',
#   '572',
#   '589',
#   '602',
#   '602',
#   '614',
#   '634',
#   '648',
#   '665',
#   '669',
#   '712',
#   '749',
#   '794',
#   '787',
#   '800',
#   ''],
#  ['Costa Rica',
#   '7377',
#   '7509',
#   '8009',
#   '8372',
#   '8645',
#   '8742',
#   '8681',
#   '8942',
#   '9246',
#   '9239',
#   '9313',
#   '9467',
#   '9626',
#   '9888',
#   '10217',
#   '10520',
#   '11226',
#   '12022',
#   '12502',
#   '12049',
#   '12485',
#   '12850',
#   '13339',
#   '13408',
#   '13648',
#   '13952',
#   '14393',
#   '14619',
#   '14790',
#   ''],
#  ['Croatia',
#   '14413',
#   '11436',
#   '10042',
#   '9329',
#   '9979',
#   '12742',
#   '13650',
#   '14668',
#   '14861',
#   '14585',
#   '15316',
#   '16477',
#   '17372',
#   '18032',
#   '19033',
#   '19692',
#   '20598',
#   '21755',
#   '22037',
#   '20348',
#   '20177',
#   '20192',
#   '19737',
#   '19888',
#   '19960',
#   '20890',
#   '21216',
#   '22426',
#   '23061',
#   ''],
#  ['Cuba',
#   '4920',
#   '4372',
#   '3856',
#   '3261',
#   '3266',
#   '3308',
#   '3558',
#   '3642',
#   '3637',
#   '3844',
#   '4047',
#   '4182',
#   '4233',
#   '4381',
#   '4618',
#   '5138',
#   '5770',
#   '6156',
#   '6400',
#   '6428',
#   '6601',
#   '6821',
#   '7022',
#   '7208',
#   '7258',
#   '7567',
#   '7597',
#   '7726',
#   '7811',
#   ' c'],
#  ['Cyprus',
#   '22853',
#   '22430',
#   '23807',
#   '23422',
#   '24226',
#   '24254',
#   '24222',
#   '24348',
#   '27786',
#   '26406',
#   '26855',
#   '28026',
#   '29381',
#   '30101',
#   '30670',
#   '31873',
#   '32716',
#   '33342',
#   '35274',
#   '32678',
#   '32881',
#   '33145',
#   '30718',
#   '28727',
#   '28908',
#   '31057',
#   '31358',
#   '32219',
#   '33100',
#   ''],
#  ['Czechia',
#   '20121',
#   '17774',
#   '17803',
#   '17759',
#   '18272',
#   '19080',
#   '19789',
#   '19701',
#   '19644',
#   '19865',
#   '20752',
#   '21241',
#   '21468',
#   '22284',
#   '23059',
#   '24572',
#   '25777',
#   '26958',
#   '27441',
#   '25796',
#   '26237',
#   '26617',
#   '26761',
#   '26672',
#   '27119',
#   '28498',
#   '29211',
#   '30530',
#   '31597',
#   ''],
#  ["C̫te d'Ivoire",
#   '2806',
#   '2759',
#   '2686',
#   '2579',
#   '2600',
#   '2704',
#   '2865',
#   '2925',
#   '3025',
#   '2975',
#   '2713',
#   '2590',
#   '2462',
#   '2311',
#   '2402',
#   '2580',
#   '2559',
#   '2548',
#   '2562',
#   '2580',
#   '2573',
#   '2398',
#   '2609',
#   '2741',
#   '2962',
#   '3126',
#   '3387',
#   '3426',
#   '3589',
#   ''],
#  ['Denmark',
#   '32832',
#   '33151',
#   '33764',
#   '33822',
#   '35550',
#   '36598',
#   '37386',
#   '38503',
#   '39365',
#   '40538',
#   '41414',
#   '41935',
#   '42090',
#   '42283',
#   '43731',
#   '44929',
#   '46716',
#   '46609',
#   '46379',
#   '43817',
#   '44726',
#   '45340',
#   '45340',
#   '45983',
#   '46714',
#   '47213',
#   '47729',
#   '48338',
#   '48836',
#   ''],
#  ['Djibouti',
#   '1919',
#   '1819',
#   '1877',
#   '1970',
#   '1881',
#   '1969',
#   '1824',
#   '1858',
#   '1801',
#   '1845',
#   '1822',
#   '1805',
#   '1837',
#   '1966',
#   '2022',
#   '2048',
#   '2303',
#   '2365',
#   '2415',
#   '2451',
#   '2494',
#   '2562',
#   '2638',
#   '2823',
#   '3003',
#   '3231',
#   '3431',
#   '3469',
#   '3601',
#   ' d'],
#  ['Dominica',
#   '6484',
#   '6505',
#   '6648',
#   '6801',
#   '6674',
#   '6823',
#   '6933',
#   '7184',
#   '7568',
#   '7394',
#   '7251',
#   '7608',
#   '7294',
#   '7772',
#   '7873',
#   '7999',
#   '8730',
#   '9197',
#   '9916',
#   '9921',
#   '10074',
#   '10027',
#   '9746',
#   '9777',
#   '10163',
#   '9804',
#   '10179',
#   '9218',
#   '9245',
#   ''],
#  ['Dominican Republic',
#   '5278',
#   '5204',
#   '5734',
#   '5946',
#   '6033',
#   '6263',
#   '6572',
#   '7037',
#   '7381',
#   '7683',
#   '7930',
#   '8007',
#   '8251',
#   '7829',
#   '7776',
#   '8665',
#   '9373',
#   '9927',
#   '10265',
#   '10233',
#   '10955',
#   '11137',
#   '11290',
#   '11613',
#   '12334',
#   '13127',
#   '13801',
#   '14197',
#   '15074',
#   ''],
#  ['Ecuador',
#   '6878',
#   '7110',
#   '7193',
#   '7249',
#   '7420',
#   '7450',
#   '7395',
#   '7584',
#   '7641',
#   '6969',
#   '6897',
#   '7170',
#   '7372',
#   '7425',
#   '7873',
#   '8197',
#   '8447',
#   '8485',
#   '9013',
#   '8951',
#   '9168',
#   '9727',
#   '10136',
#   '10482',
#   '10702',
#   '10524',
#   '10208',
#   '10220',
#   '10141',
#   ''],
#  ['Egypt',
#   '5750',
#   '5874',
#   '5999',
#   '6045',
#   '6156',
#   '6322',
#   '6512',
#   '6733',
#   '6991',
#   '7238',
#   '7545',
#   '7676',
#   '7725',
#   '7809',
#   '7986',
#   '8119',
#   '8590',
#   '9076',
#   '9547',
#   '9734',
#   '9828',
#   '9727',
#   '9750',
#   '9712',
#   '9793',
#   '10069',
#   '10323',
#   '10473',
#   '10744',
#   ''],
#  ['El Salvador',
#   '4385',
#   '4387',
#   '4674',
#   '4887',
#   '5076',
#   '5260',
#   '5235',
#   '5326',
#   '5424',
#   '5435',
#   '5480',
#   '5490',
#   '5520',
#   '5538',
#   '5553',
#   '5676',
#   '5937',
#   '6026',
#   '6168',
#   '5951',
#   '6096',
#   '6295',
#   '6373',
#   '6454',
#   '6534',
#   '6645',
#   '6745',
#   '6832',
#   '6973',
#   ''],
#  ['Equatorial Guinea',
#   '1424',
#   '1399',
#   '1855',
#   '1956',
#   '1849',
#   '1902',
#   '2958',
#   '7721',
#   '8211',
#   '10591',
#   '9269',
#   '9046',
#   '11720',
#   '10477',
#   '12505',
#   '21113',
#   '26834',
#   '30141',
#   '29473',
#   '29598',
#   '21716',
#   '22402',
#   '23988',
#   '23247',
#   '22773',
#   '23456',
#   '21365',
#   '19494',
#   '17796',
#   ''],
#  ['Eritrea',
#   '895',
#   '996',
#   '1533',
#   '1754',
#   '2146',
#   '2250',
#   '2408',
#   '2617',
#   '2678',
#   '2648',
#   '2484',
#   '2598',
#   '2548',
#   '2359',
#   '2281',
#   '2265',
#   '2177',
#   '2153',
#   '1895',
#   '1932',
#   '1941',
#   '2084',
#   '1572',
#   '1613',
#   '1626',
#   '1633',
#   '1627',
#   '1670',
#   '1708',
#   ' d'],
#  ['Estonia',
#   '15020',
#   '13965',
#   '11494',
#   '10529',
#   '10535',
#   '11443',
#   '12174',
#   '13292',
#   '14075',
#   '13934',
#   '15180',
#   '16115',
#   '17204',
#   '18442',
#   '19785',
#   '21972',
#   '24054',
#   '25555',
#   '24619',
#   '21516',
#   '21539',
#   '23313',
#   '24661',
#   '25678',
#   '26334',
#   '27001',
#   '27915',
#   '29320',
#   '30379',
#   ''],
#  ['Eswatini (Kingdom of)',
#   '5927',
#   '5914',
#   '5978',
#   '5855',
#   '5593',
#   '6092',
#   '6391',
#   '6468',
#   '6256',
#   '6458',
#   '6286',
#   '6598',
#   '6430',
#   '6513',
#   '6864',
#   '7662',
#   '7665',
#   '8015',
#   '7917',
#   '7825',
#   '7819',
#   '8317',
#   '8663',
#   '9288',
#   '9331',
#   '9362',
#   '9457',
#   '9396',
#   '9359',
#   ''],
#  ['Ethiopia',
#   '651',
#   '584',
#   '514',
#   '558',
#   '556',
#   '573',
#   '626',
#   '622',
#   '585',
#   '599',
#   '617',
#   '650',
#   '640',
#   '608',
#   '673',
#   '734',
#   '792',
#   '861',
#   '928',
#   '980',
#   '1071',
#   '1159',
#   '1224',
#   '1316',
#   '1410',
#   '1512',
#   '1612',
#   '1714',
#   '1782',
#   ''],
#  ['Fiji',
#   '5683',
#   '5517',
#   '5758',
#   '5796',
#   '5920',
#   '6162',
#   '6429',
#   '6191',
#   '6114',
#   '6603',
#   '6807',
#   '6728',
#   '7047',
#   '7056',
#   '7412',
#   '7536',
#   '7216',
#   '7208',
#   '7184',
#   '7165',
#   '7125',
#   '7293',
#   '7331',
#   '7812',
#   '8016',
#   '8391',
#   '8588',
#   '8799',
#   '79110',
#   ''],
#  ['Finland',
#   '28133',
#   '26110',
#   '24833',
#   '24381',
#   '25523',
#   '26722',
#   '27824',
#   '29720',
#   '31096',
#   '32739',
#   '34658',
#   '35692',
#   '36333',
#   '36626',
#   '38468',
#   '39285',
#   '40934',
#   '42604',
#   '42656',
#   '39370',
#   '40389',
#   '40868',
#   '40120',
#   '39563',
#   '39372',
#   '39473',
#   '40609',
#   '41142',
#   '41779',
#   ''],
#  ['France',
#   '29573',
#   '29692',
#   '30056',
#   '29766',
#   '30307',
#   '30836',
#   '31323',
#   '32057',
#   '33115',
#   '34307',
#   '35261',
#   '35779',
#   '35655',
#   '35796',
#   '36558',
#   '37005',
#   '37751',
#   '38425',
#   '38379',
#   '37135',
#   '37674',
#   '38436',
#   '38194',
#   '38240',
#   '38397',
#   '38668',
#   '38926',
#   '39935',
#   '40511',
#   ''],
#  ['Gabon',
#   '19368',
#   '20053',
#   '18489',
#   '18512',
#   '19119',
#   '19311',
#   '19454',
#   '19913',
#   '20875',
#   '18165',
#   '16125',
#   '17023',
#   '17194',
#   '16870',
#   '15552',
#   '16335',
#   '14626',
#   '14715',
#   '13543',
#   '14200',
#   '13960',
#   '13814',
#   '15005',
#   '15519',
#   '16906',
#   '16336',
#   '16339',
#   '16213',
#   '15794',
#   ''],
#  ['Gambia',
#   '1329',
#   '1393',
#   '1395',
#   '1394',
#   '1354',
#   '1331',
#   '1320',
#   '1328',
#   '1332',
#   '1366',
#   '1393',
#   '1417',
#   '1312',
#   '1373',
#   '1440',
#   '1383',
#   '1353',
#   '1369',
#   '1414',
#   '1454',
#   '1503',
#   '1390',
#   '1429',
#   '1468',
#   '1409',
#   '1446',
#   '1416',
#   '1437',
#   '1490',
#   ''],
#  ['Georgia',
#   '7988',
#   '6258',
#   '3399',
#   '2360',
#   '2146',
#   '2224',
#   '2622',
#   '3173',
#   '3406',
#   '3576',
#   '3664',
#   '3794',
#   '4011',
#   '4485',
#   '4831',
#   '5299',
#   '5896',
#   '6561',
#   '6623',
#   '6455',
#   '6769',
#   '7325',
#   '8012',
#   '8225',
#   '8688',
#   '8748',
#   '8768',
#   '9146',
#   '9570',
#   ''],
#  ['Germany',
#   '31793',
#   '32995',
#   '33325',
#   '32732',
#   '33196',
#   '33594',
#   '33807',
#   '34311',
#   '34853',
#   '35458',
#   '36529',
#   '37019',
#   '36821',
#   '36649',
#   '37694',
#   '38051',
#   '39828',
#   '41080',
#   '41393',
#   '39673',
#   '41236',
#   '43770',
#   '43827',
#   '43888',
#   '44529',
#   '45012',
#   '45577',
#   '46438',
#   '46946',
#   ''],
#  ['Ghana',
#   '1863',
#   '1907',
#   '1928',
#   '1960',
#   '1966',
#   '1992',
#   '2030',
#   '2065',
#   '2108',
#   '2145',
#   '2152',
#   '2205',
#   '2247',
#   '2305',
#   '2372',
#   '2475',
#   '2583',
#   '2627',
#   '2799',
#   '2863',
#   '2977',
#   '3264',
#   '3408',
#   '3687',
#   '3663',
#   '3735',
#   '3756',
#   '3943',
#   '4099',
#   ''],
#  ['Greece',
#   '21080',
#   '21554',
#   '21596',
#   '21073',
#   '21404',
#   '21752',
#   '22203',
#   '23101',
#   '23840',
#   '24194',
#   '24924',
#   '25891',
#   '26724',
#   '28009',
#   '29326',
#   '29203',
#   '30556',
#   '31243',
#   '30930',
#   '29749',
#   '28134',
#   '25428',
#   '24521',
#   '23714',
#   '24242',
#   '24165',
#   '24187',
#   '24647',
#   '24909',
#   ''],
#  ['Grenada',
#   '6929',
#   '7161',
#   '7089',
#   '6804',
#   '6843',
#   '6837',
#   '7070',
#   '7374',
#   '8127',
#   '8631',
#   '8919',
#   '8566',
#   '8746',
#   '9568',
#   '9232',
#   '11224',
#   '10740',
#   '11218',
#   '11325',
#   '10209',
#   '10445',
#   '10590',
#   '10382',
#   '10640',
#   '10689',
#   '11011',
#   '11650',
#   '12155',
#   '12684',
#   ''],
#  ['Guatemala',
#   '4969',
#   '5107',
#   '5217',
#   '5313',
#   '5402',
#   '5535',
#   '5550',
#   '5670',
#   '5845',
#   '5925',
#   '6002',
#   '6041',
#   '6063',
#   '6077',
#   '6108',
#   '6160',
#   '6316',
#   '6552',
#   '6641',
#   '6501',
#   '6537',
#   '6630',
#   '6747',
#   '6867',
#   '6976',
#   '7128',
#   '7199',
#   '7283',
#   '7378',
#   ''],
#  ['Guinea',
#   '1272',
#   '1270',
#   '1292',
#   '1346',
#   '1368',
#   '1394',
#   '1416',
#   '1442',
#   '1451',
#   '1486',
#   '1486',
#   '1498',
#   '1576',
#   '1470',
#   '1471',
#   '1451',
#   '1491',
#   '1570',
#   '1564',
#   '1511',
#   '1559',
#   '1604',
#   '1676',
#   '1714',
#   '1775',
#   '1805',
#   '1971',
#   '2201',
#   '2211',
#   ''],
#  ['Guinea-Bissau',
#   '1565',
#   '1570',
#   '1563',
#   '1552',
#   '1575',
#   '1592',
#   '1745',
#   '1850',
#   '1287',
#   '1281',
#   '1366',
#   '1353',
#   '1336',
#   '1312',
#   '1322',
#   '1347',
#   '1359',
#   '1376',
#   '1369',
#   '1386',
#   '1424',
#   '1516',
#   '1449',
#   '1422',
#   '1477',
#   '1513',
#   '1570',
#   '1580',
#   '1593',
#   ''],
#  ['Guyana',
#   '2097',
#   '1865',
#   '2299',
#   '2798',
#   '3199',
#   '3409',
#   '3958',
#   '4108',
#   '4151',
#   '4202',
#   '4332',
#   '4391',
#   '4425',
#   '4481',
#   '4631',
#   '4612',
#   '5120',
#   '5427',
#   '5462',
#   '5652',
#   '5793',
#   '6085',
#   '6398',
#   '6622',
#   '6846',
#   '7032',
#   '7294',
#   '7443',
#   '7615',
#   ''],
#  ['Haiti',
#   '2091',
#   '2093',
#   '1942',
#   '1807',
#   '1566',
#   '1697',
#   '1740',
#   '1752',
#   '1756',
#   '1770',
#   '1762',
#   '1705',
#   '1662',
#   '1638',
#   '1559',
#   '1549',
#   '1580',
#   '1607',
#   '1596',
#   '1623',
#   '1513',
#   '1577',
#   '1603',
#   '1639',
#   '1666',
#   '1661',
#   '1666',
#   '1664',
#   '1665',
#   ''],
#  ['Honduras',
#   '3027',
#   '2825',
#   '2893',
#   '3059',
#   '2973',
#   '3062',
#   '3034',
#   '3125',
#   '3159',
#   '3072',
#   '3188',
#   '3181',
#   '3203',
#   '3246',
#   '3344',
#   '3480',
#   '3618',
#   '3818',
#   '3878',
#   '3681',
#   '3731',
#   '3764',
#   '3799',
#   '3825',
#   '3836',
#   '3955',
#   '4032',
#   '4148',
#   '4258',
#   ''],
#  ['Hong Kong; China (SAR)',
#   '26175',
#   '27273',
#   '28669',
#   '31307',
#   '32332',
#   '32678',
#   '31988',
#   '33624',
#   '32084',
#   '32598',
#   '34330',
#   '34822',
#   '34629',
#   '36489',
#   '39142',
#   '41166',
#   '44578',
#   '47452',
#   '49409',
#   '46785',
#   '49139',
#   '51454',
#   '51114',
#   '52725',
#   '53886',
#   '54608',
#   '55816',
#   '58553',
#   '60221',
#   ''],
#  ['Hungary',
#   '16200',
#   '14059',
#   '13730',
#   '14255',
#   '14671',
#   '14829',
#   '14780',
#   '15057',
#   '15702',
#   '16222',
#   '17091',
#   '17768',
#   '18585',
#   '19471',
#   '20315',
#   '21235',
#   '22165',
#   '21944',
#   '22297',
#   '21195',
#   '21359',
#   '21784',
#   '21692',
#   '22515',
#   '23154',
#   '23965',
#   '25081',
#   '25774',
#   '27144',
#   ''],
#  ['Iceland',
#   '29373',
#   '29182',
#   '27957',
#   '27987',
#   '28551',
#   '28511',
#   '29864',
#   '30490',
#   '32247',
#   '33156',
#   '33726',
#   '34752',
#   '35906',
#   '36075',
#   '37491',
#   '38782',
#   '38860',
#   '42014',
#   '35114',
#   '33274',
#   '32619',
#   '34552',
#   '35944',
#   '40400',
#   '40701',
#   '42182',
#   '44809',
#   '46817',
#   '47566',
#   ''],
#  ['India',
#   '1882',
#   '1859',
#   '1922',
#   '1977',
#   '2070',
#   '2188',
#   '2313',
#   '2364',
#   '2465',
#   '2637',
#   '2683',
#   '2769',
#   '2832',
#   '3002',
#   '3189',
#   '3387',
#   '3602',
#   '3833',
#   '3887',
#   '4134',
#   '4403',
#   '4584',
#   '4760',
#   '5001',
#   '5315',
#   '5674',
#   '6075',
#   '6446',
#   '6829',
#   ''],
#  ['Indonesia',
#   '4399',
#   '4628',
#   '4847',
#   '5130',
#   '5493',
#   '5838',
#   '6217',
#   '6399',
#   '5328',
#   '5185',
#   '5422',
#   '5717',
#   '5938',
#   '6084',
#   '6256',
#   '6506',
#   '6816',
#   '7164',
#   '7539',
#   '7788',
#   '8234',
#   '8614',
#   '9011',
#   '9370',
#   '9679',
#   '10029',
#   '10419',
#   '10811',
#   '11256',
#   ''],
#  ['Iran (Islamic Republic of)',
#   '11391',
#   '12497',
#   '12606',
#   '12565',
#   '12080',
#   '12362',
#   '12585',
#   '12585',
#   '12781',
#   '12584',
#   '13228',
#   '13178',
#   '13989',
#   '15013',
#   '15435',
#   '15737',
#   '16373',
#   '17554',
#   '17416',
#   '17337',
#   '18142',
#   '18402',
#   '16938',
#   '16696',
#   '17177',
#   '16720',
#   '18710',
#   '19127',
#   '18166',
#   ''],
#  ['Iraq',
#   '11382',
#   '3983',
#   '5156',
#   '6595',
#   '6645',
#   '6578',
#   '7080',
#   '8215',
#   '10737',
#   '12192',
#   '12135',
#   '12040',
#   '10774',
#   '7138',
#   '10727',
#   '11092',
#   '11972',
#   '11972',
#   '13200',
#   '13042',
#   '13305',
#   '13679',
#   '15106',
#   '15401',
#   '15024',
#   '14853',
#   '16387',
#   '15650',
#   '15365',
#   ''],
#  ['Ireland',
#   '19935',
#   '20286',
#   '20557',
#   '21098',
#   '22327',
#   '23944',
#   '25744',
#   '27828',
#   '29704',
#   '31589',
#   '34066',
#   '34511',
#   '35262',
#   '36806',
#   '38755',
#   '40180',
#   '41630',
#   '42012',
#   '39387',
#   '35691',
#   '36300',
#   '36449',
#   '36116',
#   '38059',
#   '41208',
#   '45809',
#   '50911',
#   '52799',
#   '55660',
#   ''],
#  ['Israel',
#   '20001',
#   '20469',
#   '21259',
#   '21553',
#   '22535',
#   '23489',
#   '23984',
#   '24212',
#   '24526',
#   '24420',
#   '25092',
#   '25073',
#   '24713',
#   '24510',
#   '25287',
#   '26375',
#   '27494',
#   '28643',
#   '28431',
#   '27942',
#   '29110',
#   '30157',
#   '29852',
#   '30679',
#   '31728',
#   '31814',
#   '32428',
#   '32860',
#   '33650',
#   ''],
#  ['Italy',
#   '30729',
#   '31124',
#   '31315',
#   '31104',
#   '31717',
#   '32742',
#   '33237',
#   '34007',
#   '34513',
#   '35174',
#   '36394',
#   '37046',
#   '37030',
#   '36907',
#   '37370',
#   '37661',
#   '38392',
#   '38642',
#   '37608',
#   '35688',
#   '36128',
#   '36251',
#   '35178',
#   '34161',
#   '33946',
#   '34105',
#   '34818',
#   '35573',
#   '36141',
#   ''],
#  ['Jamaica',
#   '6597',
#   '6804',
#   '7013',
#   '8003',
#   '7797',
#   '7963',
#   '8099',
#   '7882',
#   '7638',
#   '7630',
#   '7621',
#   '7593',
#   '7562',
#   '7826',
#   '7902',
#   '7904',
#   '8165',
#   '8243',
#   '8241',
#   '7730',
#   '7714',
#   '7821',
#   '7886',
#   '7802',
#   '7806',
#   '7751',
#   '7721',
#   '7870',
#   '7932',
#   ''],
#  ['Japan',
#   '30836',
#   '31774',
#   '32015',
#   '31781',
#   '31974',
#   '32731',
#   '33768',
#   '34084',
#   '33586',
#   '33437',
#   '34386',
#   '34477',
#   '34399',
#   '34906',
#   '35770',
#   '36461',
#   '37114',
#   '37821',
#   '37233',
#   '35175',
#   '36685',
#   '36788',
#   '37341',
#   '38387',
#   '38669',
#   '39297',
#   '39407',
#   '40343',
#   '40799',
#   ''],
#  ['Jordan',
#   '5880',
#   '5514',
#   '6319',
#   '6332',
#   '6354',
#   '6563',
#   '6489',
#   '6651',
#   '6804',
#   '6900',
#   '7312',
#   '7607',
#   '7804',
#   '7997',
#   '8514',
#   '8910',
#   '9303',
#   '9726',
#   '9827',
#   '9830',
#   '9306',
#   '9041',
#   '8759',
#   '8574',
#   '8432',
#   '8308',
#   '8253',
#   '8253',
#   '8268',
#   ''],
#  ['Kazakhstan',
#   '13703',
#   '12202',
#   '11595',
#   '10600',
#   '9374',
#   '8740',
#   '8897',
#   '9164',
#   '9152',
#   '9308',
#   '9910',
#   '11427',
#   '12669',
#   '13643',
#   '14676',
#   '15417',
#   '16254',
#   '17233',
#   '16858',
#   '17686',
#   '17928',
#   '18215',
#   '19169',
#   '21010',
#   '21706',
#   '23175',
#   '22062',
#   '22025',
#   '22168',
#   ''],
#  ['Kenya',
#   '2265',
#   '2213',
#   '2130',
#   '2027',
#   '2037',
#   '2098',
#   '2157',
#   '2117',
#   '2135',
#   '2116',
#   '2077',
#   '2096',
#   '2055',
#   '2055',
#   '2107',
#   '2188',
#   '2261',
#   '2346',
#   '2295',
#   '2306',
#   '2427',
#   '2516',
#   '2550',
#   '2614',
#   '2676',
#   '2768',
#   '2875',
#   '2936',
#   '3052',
#   ''],
#  ['Kiribati',
#   '2358',
#   '3058',
#   '3075',
#   '2930',
#   '2922',
#   '3041',
#   '2620',
#   '3114',
#   '3448',
#   '3085',
#   '3234',
#   '3333',
#   '3151',
#   '2977',
#   '2880',
#   '2814',
#   '2686',
#   '2726',
#   '2661',
#   '2489',
#   '2565',
#   '2434',
#   '2730',
#   '3092',
#   '3453',
#   '4050',
#   '3985',
#   '3971',
#   '3917',
#   ''],
#  ['Korea (Republic of)',
#   '11614',
#   '12687',
#   '13326',
#   '14091',
#   '15213',
#   '16482',
#   '17573',
#   '18400',
#   '17121',
#   '18974',
#   '20601',
#   '21377',
#   '22902',
#   '23457',
#   '24556',
#   '25315',
#   '26600',
#   '27932',
#   '28590',
#   '28579',
#   '30387',
#   '31412',
#   '32099',
#   '32781',
#   '33534',
#   '34276',
#   '35122',
#   '35945',
#   '36757',
#   ''],
#  ['Kuwait',
#   '52301',
#   '34139',
#   '56057',
#   '73710',
#   '82558',
#   '95142',
#   '93274',
#   '94232',
#   '92690',
#   '81480',
#   '81957',
#   '77739',
#   '75124',
#   '85776',
#   '94816',
#   '101314',
#   '106011',
#   '106529',
#   '99649',
#   '88457',
#   '80290',
#   '82672',
#   '84858',
#   '81594',
#   '79290',
#   '75582',
#   '76145',
#   '73742',
#   '71164',
#   ''],
#  ['Kyrgyzstan',
#   '3420',
#   '3096',
#   '2639',
#   '2224',
#   '1758',
#   '1634',
#   '1728',
#   '1846',
#   '1843',
#   '1859',
#   '1932',
#   '2056',
#   '2043',
#   '2169',
#   '2265',
#   '2258',
#   '2343',
#   '2527',
#   '2649',
#   '2700',
#   '2601',
#   '2610',
#   '2761',
#   '2923',
#   '3021',
#   '3082',
#   '3108',
#   '3199',
#   '3317',
#   ''],
#  ["Lao People's Democratic Republic",
#   '1732',
#   '1756',
#   '1804',
#   '1861',
#   '1961',
#   '2047',
#   '2142',
#   '2198',
#   '2232',
#   '2386',
#   '2419',
#   '2515',
#   '2627',
#   '2698',
#   '2860',
#   '3060',
#   '3158',
#   '3418',
#   '3579',
#   '3856',
#   '3970',
#   '4181',
#   '4506',
#   '4826',
#   '5166',
#   '5460',
#   '5748',
#   '5985',
#   '6317',
#   ''],
#  ['Latvia',
#   '14077',
#   '12672',
#   '8229',
#   '7094',
#   '7241',
#   '8345',
#   '8630',
#   '9506',
#   '10214',
#   '10402',
#   '11162',
#   '12087',
#   '13080',
#   '14230',
#   '15345',
#   '17347',
#   '19305',
#   '21284',
#   '21111',
#   '19929',
#   '18481',
#   '19768',
#   '20687',
#   '21518',
#   '22094',
#   '22890',
#   '23648',
#   '24853',
#   '26301',
#   ''],
#  ['Lebanon',
#   '6794',
#   '8126',
#   '9163',
#   '9474',
#   '9887',
#   '10228',
#   '10997',
#   '10881',
#   '11050',
#   '10872',
#   '10817',
#   '10568',
#   '9972',
#   '8532',
#   '10099',
#   '10413',
#   '10623',
#   '11852',
#   '12767',
#   '13630',
#   '14212',
#   '13759',
#   '13291',
#   '12771',
#   '12197',
#   '11755',
#   '11547',
#   '11635',
#   '11136',
#   ''],
#  ['Lesotho',
#   '2053',
#   '2051',
#   '2040',
#   '1979',
#   '2021',
#   '1989',
#   '2065',
#   '2082',
#   '2019',
#   '2046',
#   '2055',
#   '2413',
#   '2440',
#   '2533',
#   '2487',
#   '2447',
#   '2456',
#   '2868',
#   '3008',
#   '2936',
#   '3044',
#   '3046',
#   '3119',
#   '3122',
#   '3121',
#   '3217',
#   '3347',
#   '3228',
#   '3244',
#   ''],
#  ['Liberia',
#   '923',
#   '806',
#   '533',
#   '361',
#   '281',
#   '261',
#   '277',
#   '531',
#   '642',
#   '619',
#   '1209',
#   '1162',
#   '1157',
#   '781',
#   '869',
#   '889',
#   '926',
#   '988',
#   '1016',
#   '1004',
#   '1020',
#   '1094',
#   '1108',
#   '1174',
#   '1152',
#   '1137',
#   '1091',
#   '1085',
#   '1040',
#   ''],
#  ['Libya',
#   '20344',
#   '22970',
#   '21835',
#   '20561',
#   '20524',
#   '19677',
#   '19747',
#   '20462',
#   '19476',
#   '19271',
#   '19377',
#   '19208',
#   '18774',
#   '21036',
#   '21029',
#   '22871',
#   '24589',
#   '25347',
#   '28539',
#   '28040',
#   '28751',
#   '11114',
#   '24327',
#   '11856',
#   '9285',
#   '9048',
#   '8799',
#   '10997',
#   '11685',
#   ' e'],
#  ['Liechtenstein',
#   '63874',
#   '64199',
#   '65629',
#   '67508',
#   '71074',
#   '74144',
#   '78080',
#   '82454',
#   '87531',
#   '93739',
#   '96864',
#   '87255',
#   '83956',
#   '79121',
#   '78206',
#   '84033',
#   '93239',
#   '103380',
#   '100278',
#   '85104',
#   '89070',
#   '79352',
#   '70267',
#   '92611',
#   '95536',
#   '96869',
#   '97351',
#   '98006',
#   '99732',
#   ' b;f'],
#  ['Lithuania',
#   '15932',
#   '15044',
#   '11890',
#   '10000',
#   '9068',
#   '9340',
#   '9809',
#   '10609',
#   '11444',
#   '11378',
#   '11969',
#   '12913',
#   '13939',
#   '15310',
#   '16587',
#   '18273',
#   '19834',
#   '21881',
#   '22756',
#   '20672',
#   '20672',
#   '22015',
#   '23326',
#   '24492',
#   '25912',
#   '25924',
#   '26860',
#   '28375',
#   '29775',
#   ''],
#  ['Luxembourg',
#   '60153',
#   '65016',
#   '64709',
#   '65820',
#   '65181',
#   '67316',
#   '67406',
#   '72978',
#   '73360',
#   '76148',
#   '79992',
#   '83182',
#   '77611',
#   '71406',
#   '82808',
#   '84855',
#   '77291',
#   '91519',
#   '86052',
#   '62099',
#   '66588',
#   '63525',
#   '62078',
#   '60205',
#   '60323',
#   '62935',
#   '62818',
#   '65101',
#   '65543',
#   ''],
#  ['Madagascar',
#   '1590',
#   '1416',
#   '1416',
#   '1409',
#   '1354',
#   '1334',
#   '1334',
#   '1358',
#   '1375',
#   '1406',
#   '1418',
#   '1464',
#   '1236',
#   '1319',
#   '1342',
#   '1368',
#   '1397',
#   '1452',
#   '1515',
#   '1407',
#   '1371',
#   '1346',
#   '1326',
#   '1320',
#   '1332',
#   '1323',
#   '1339',
#   '1374',
#   '1404',
#   ''],
#  ['Malawi',
#   '730',
#   '779',
#   '715',
#   '784',
#   '689',
#   '799',
#   '856',
#   '869',
#   '871',
#   '873',
#   '866',
#   '804',
#   '803',
#   '828',
#   '852',
#   '859',
#   '876',
#   '938',
#   '982',
#   '1028',
#   '1061',
#   '1082',
#   '1062',
#   '1078',
#   '1112',
#   '1110',
#   '1130',
#   '1149',
#   '1159',
#   ''],
#  ['Malaysia',
#   '10175',
#   '10775',
#   '11402',
#   '12273',
#   '13073',
#   '13997',
#   '15003',
#   '15591',
#   '14053',
#   '14330',
#   '15071',
#   '14973',
#   '15559',
#   '16296',
#   '17078',
#   '17757',
#   '18661',
#   '19606',
#   '19950',
#   '19515',
#   '20374',
#   '21290',
#   '21836',
#   '22641',
#   '23686',
#   '24703',
#   '25394',
#   '26555',
#   '27227',
#   ''],
#  ['Maldives',
#   '6261',
#   '6327',
#   '6556',
#   '6663',
#   '7112',
#   '7388',
#   '7826',
#   '8285',
#   '8771',
#   '9135',
#   '9332',
#   '8931',
#   '9350',
#   '10249',
#   '10633',
#   '9006',
#   '11092',
#   '10184',
#   '11215',
#   '10287',
#   '10526',
#   '11162',
#   '11105',
#   '11185',
#   '11654',
#   '11658',
#   '11978',
#   '12234',
#   '12549',
#   ''],
#  ['Mali',
#   '1271',
#   '1397',
#   '1317',
#   '1328',
#   '1327',
#   '1295',
#   '1350',
#   '1377',
#   '1445',
#   '1495',
#   '1457',
#   '1571',
#   '1551',
#   '1687',
#   '1661',
#   '1715',
#   '1726',
#   '1747',
#   '1778',
#   '1798',
#   '1804',
#   '1811',
#   '1734',
#   '1744',
#   '1813',
#   '1868',
#   '1904',
#   '1964',
#   '1965',
#   ''],
#  ['Malta',
#   '17386',
#   '17760',
#   '18161',
#   '18609',
#   '19122',
#   '20040',
#   '20490',
#   '21394',
#   '21911',
#   '23432',
#   '24095',
#   '24782',
#   '25235',
#   '25447',
#   '25466',
#   '25498',
#   '25754',
#   '26809',
#   '27708',
#   '25659',
#   '26854',
#   '27670',
#   '27927',
#   '28688',
#   '30663',
#   '32640',
#   '32619',
#   '33461',
#   '34795',
#   ''],
#  ['Marshall Islands',
#   '3737',
#   '3650',
#   '3839',
#   '4015',
#   '4206',
#   '4592',
#   '3947',
#   '3773',
#   '3800',
#   '3806',
#   '4015',
#   '4170',
#   '4106',
#   '3989',
#   '3938',
#   '3982',
#   '3951',
#   '4035',
#   '3926',
#   '3858',
#   '3923',
#   '3978',
#   '3956',
#   '4148',
#   '4314',
#   '4605',
#   '4506',
#   '4587',
#   '4633',
#   ''],
#  ['Mauritania',
#   '2675',
#   '2699',
#   '2688',
#   '2752',
#   '2596',
#   '2779',
#   '3047',
#   '2840',
#   '2866',
#   '3015',
#   '2896',
#   '2780',
#   '2901',
#   '2978',
#   '3058',
#   '3221',
#   '3511',
#   '3536',
#   '3522',
#   '3461',
#   '3398',
#   '3379',
#   '3449',
#   '3566',
#   '3629',
#   '3622',
#   '3636',
#   '3682',
#   '3746',
#   ''],
#  ['Mauritius',
#   '7503',
#   '7830',
#   '8243',
#   '8540',
#   '8703',
#   '9016',
#   '9374',
#   '9840',
#   '10306',
#   '10468',
#   '11219',
#   '11576',
#   '11680',
#   '12189',
#   '12674',
#   '12835',
#   '13506',
#   '14491',
#   '15056',
#   '15351',
#   '15783',
#   '16247',
#   '17590',
#   '18760',
#   '19421',
#   '20188',
#   '20893',
#   '21966',
#   '22724',
#   ''],
#  ['Mexico',
#   '13156',
#   '13535',
#   '13775',
#   '13836',
#   '14260',
#   '12963',
#   '13671',
#   '14502',
#   '15021',
#   '15264',
#   '15790',
#   '15554',
#   '15356',
#   '15362',
#   '15781',
#   '15814',
#   '16386',
#   '16488',
#   '16476',
#   '15334',
#   '15970',
#   '16258',
#   '16568',
#   '16411',
#   '16757',
#   '17074',
#   '17344',
#   '17533',
#   '17628',
#   ''],
#  ['Micronesia (Federated States of)',
#   '3330',
#   '3390',
#   '3336',
#   '3349',
#   '3276',
#   '3299',
#   '3163',
#   '3133',
#   '3019',
#   '3056',
#   '3204',
#   '3251',
#   '3267',
#   '3321',
#   '3267',
#   '3366',
#   '3387',
#   '3372',
#   '3284',
#   '3443',
#   '3439',
#   '3519',
#   '3468',
#   '3395',
#   '3272',
#   '3728',
#   '3635',
#   '3700',
#   '3700',
#   ''],
#  ['Moldova (Republic of)',
#   '6743',
#   '5552',
#   '3902',
#   '3871',
#   '2686',
#   '3104',
#   '3062',
#   '3104',
#   '2892',
#   '2799',
#   '2852',
#   '3172',
#   '3431',
#   '3845',
#   '4175',
#   '4457',
#   '4673',
#   '4727',
#   '5117',
#   '4648',
#   '5073',
#   '5357',
#   '5454',
#   '5956',
#   '6212',
#   '6032',
#   '6292',
#   '6603',
#   '6833',
#   ''],
#  ['Mongolia',
#   '5048',
#   '4608',
#   '4058',
#   '3837',
#   '3946',
#   '4176',
#   '4269',
#   '4401',
#   '4558',
#   '4656',
#   '4646',
#   '4753',
#   '4922',
#   '5192',
#   '5689',
#   '5938',
#   '6417',
#   '6905',
#   '7351',
#   '7057',
#   '7086',
#   '8124',
#   '8981',
#   '10079',
#   '10384',
#   '10435',
#   '10324',
#   '9892',
#   '10784',
#   ''],
#  ['Montenegro',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '10917',
#   '10987',
#   '11214',
#   '11472',
#   '11884',
#   '11885',
#   '12959',
#   '13767',
#   '14786',
#   '13706',
#   '13921',
#   '14589',
#   '14310',
#   '14847',
#   '15001',
#   '15647',
#   '15883',
#   '16855',
#   '17511',
#   ''],
#  ['Morocco',
#   '3809',
#   '4000',
#   '3860',
#   '3744',
#   '4095',
#   '3797',
#   '4240',
#   '4114',
#   '4383',
#   '4378',
#   '4402',
#   '4673',
#   '4777',
#   '5012',
#   '5211',
#   '5349',
#   '5680',
#   '5824',
#   '6104',
#   '6210',
#   '6366',
#   '6591',
#   '6671',
#   '6923',
#   '6939',
#   '7183',
#   '7169',
#   '7342',
#   '7480',
#   ''],
#  ['Mozambique',
#   '373',
#   '381',
#   '340',
#   '357',
#   '364',
#   '365',
#   '456',
#   '495',
#   '538',
#   '571',
#   '554',
#   '604',
#   '590',
#   '666',
#   '687',
#   '723',
#   '749',
#   '792',
#   '829',
#   '886',
#   '913',
#   '970',
#   '1021',
#   '1065',
#   '1103',
#   '1133',
#   '1138',
#   '1139',
#   '1154',
#   ''],
#  ['Myanmar',
#   '730',
#   '715',
#   '775',
#   '812',
#   '863',
#   '912',
#   '960',
#   '1001',
#   '1046',
#   '1146',
#   '1289',
#   '1418',
#   '1574',
#   '1775',
#   '1999',
#   '2252',
#   '2529',
#   '2814',
#   '3083',
#   '3387',
#   '3688',
#   '3864',
#   '3951',
#   '4284',
#   '4547',
#   '4863',
#   '5155',
#   '5443',
#   '5764',
#   ''],
#  ['Namibia',
#   '5821',
#   '6213',
#   '6324',
#   '6105',
#   '6051',
#   '6289',
#   '6235',
#   '6352',
#   '6474',
#   '6402',
#   '6720',
#   '6641',
#   '6965',
#   '7379',
#   '7868',
#   '7732',
#   '8205',
#   '8246',
#   '8324',
#   '8176',
#   '8348',
#   '8718',
#   '8863',
#   '9534',
#   '10011',
#   '10402',
#   '10171',
#   '9779',
#   '9683',
#   ''],
#  ['Nauru',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '7832',
#   '7071',
#   '6427',
#   '6842',
#   '5656',
#   '6051',
#   '3631',
#   '5640',
#   '5824',
#   '6901',
#   '7694',
#   '8162',
#   '9474',
#   '12321',
#   '14991',
#   '15203',
#   '16239',
#   '17345',
#   '17313',
#   ''],
#  ['Nepal',
#   '1192',
#   '1235',
#   '1252',
#   '1263',
#   '1332',
#   '1342',
#   '1381',
#   '1419',
#   '1432',
#   '1467',
#   '1532',
#   '1579',
#   '1549',
#   '1587',
#   '1637',
#   '1682',
#   '1725',
#   '1767',
#   '1854',
#   '1926',
#   '2002',
#   '2064',
#   '2172',
#   '2267',
#   '2426',
#   '2496',
#   '2486',
#   '2639',
#   '2748',
#   ''],
#  ['Netherlands',
#   '32233',
#   '32868',
#   '33079',
#   '33452',
#   '34416',
#   '35534',
#   '36660',
#   '37796',
#   '38813',
#   '41174',
#   '42776',
#   '42472',
#   '42380',
#   '42816',
#   '43297',
#   '43221',
#   '45632',
#   '46861',
#   '46360',
#   '45277',
#   '46241',
#   '47251',
#   '46735',
#   '46374',
#   '46129',
#   '46976',
#   '47008',
#   '48994',
#   '50013',
#   ''],
#  ['New Zealand',
#   '23099',
#   '21231',
#   '21294',
#   '22228',
#   '23146',
#   '24019',
#   '24213',
#   '24725',
#   '25064',
#   '25928',
#   '26615',
#   '27527',
#   '28332',
#   '29105',
#   '29558',
#   '29945',
#   '30358',
#   '30778',
#   '30197',
#   '30816',
#   '30643',
#   '31252',
#   '31911',
#   '32521',
#   '33193',
#   '33983',
#   '34538',
#   '34668',
#   '35108',
#   ''],
#  ['Nicaragua',
#   '2860',
#   '2221',
#   '2027',
#   '2058',
#   '2421',
#   '2618',
#   '2786',
#   '2898',
#   '3024',
#   '3186',
#   '3272',
#   '3300',
#   '3299',
#   '3346',
#   '3494',
#   '3631',
#   '3703',
#   '3859',
#   '3937',
#   '3733',
#   '3855',
#   '4047',
#   '4245',
#   '4397',
#   '4561',
#   '4709',
#   '4859',
#   '5025',
#   '4790',
#   ''],
#  ['Niger',
#   '872',
#   '871',
#   '791',
#   '775',
#   '775',
#   '762',
#   '771',
#   '764',
#   '818',
#   '786',
#   '748',
#   '774',
#   '765',
#   '778',
#   '755',
#   '761',
#   '778',
#   '772',
#   '812',
#   '774',
#   '806',
#   '793',
#   '843',
#   '849',
#   '884',
#   '884',
#   '892',
#   '901',
#   '912',
#   ''],
#  ['Nigeria',
#   '3221',
#   '3157',
#   '3191',
#   '2995',
#   '2912',
#   '2872',
#   '2924',
#   '2946',
#   '2936',
#   '2932',
#   '2828',
#   '3011',
#   '3381',
#   '3499',
#   '3699',
#   '3819',
#   '4166',
#   '4207',
#   '4375',
#   '4573',
#   '4793',
#   '4924',
#   '5017',
#   '5220',
#   '5494',
#   '5540',
#   '5336',
#   '5203',
#   '5086',
#   ''],
#  ['North Macedonia',
#   '9526',
#   '8999',
#   '8265',
#   '7705',
#   '7630',
#   '7570',
#   '7616',
#   '7666',
#   '7874',
#   '8126',
#   '8458',
#   '8257',
#   '8322',
#   '8482',
#   '8915',
#   '9216',
#   '9808',
#   '9985',
#   '10907',
#   '10911',
#   '11192',
#   '11404',
#   '11296',
#   '11589',
#   '12057',
#   '12338',
#   '12552',
#   '12570',
#   '12874',
#   ''],
#  ['Norway',
#   '41798',
#   '42764',
#   '44456',
#   '45390',
#   '47653',
#   '49556',
#   '51806',
#   '54283',
#   '55359',
#   '56202',
#   '57315',
#   '58984',
#   '59620',
#   '59979',
#   '61761',
#   '63509',
#   '63879',
#   '64859',
#   '64254',
#   '63017',
#   '62994',
#   '62729',
#   '63523',
#   '63573',
#   '65438',
#   '66584',
#   '66746',
#   '67529',
#   '68059',
#   ''],
#  ['Oman',
#   '34936',
#   '35829',
#   '36493',
#   '37076',
#   '37085',
#   '38098',
#   '38567',
#   '40569',
#   '41176',
#   '41093',
#   '43271',
#   '44795',
#   '43043',
#   '41579',
#   '41322',
#   '40620',
#   '38774',
#   '42549',
#   '43322',
#   '43636',
#   '42949',
#   '39387',
#   '40034',
#   '39832',
#   '37675',
#   '38837',
#   '39066',
#   '37379',
#   '37039',
#   ''],
#  ['Pakistan',
#   '3195',
#   '3199',
#   '3306',
#   '3263',
#   '3276',
#   '3361',
#   '3386',
#   '3307',
#   '3291',
#   '3321',
#   '3358',
#   '3339',
#   '3430',
#   '3605',
#   '3748',
#   '3938',
#   '4075',
#   '4170',
#   '4155',
#   '4205',
#   '4227',
#   '4278',
#   '4360',
#   '4457',
#   '4590',
#   '4727',
#   '4891',
#   '5033',
#   '5190',
#   ''],
#  ['Palau',
#   '11406',
#   '12346',
#   '11245',
#   '9967',
#   '10349',
#   '10758',
#   '11088',
#   '10885',
#   '10535',
#   '10365',
#   '11421',
#   '11973',
#   '12182',
#   '11990',
#   '12736',
#   '13786',
#   '13358',
#   '13772',
#   '13115',
#   '13342',
#   '13539',
#   '14510',
#   '14923',
#   '14267',
#   '15092',
#   '16045',
#   '16325',
#   '15981',
#   '16720',
#   ''],
#  ['Palestine; State of',
#   '1079',
#   '984',
#   '1176',
#   '1241',
#   '3641',
#   '3749',
#   '3595',
#   '3987',
#   '4584',
#   '4834',
#   '4126',
#   '3521',
#   '2958',
#   '3287',
#   '3501',
#   '3849',
#   '3650',
#   '3831',
#   '3965',
#   '4092',
#   '4287',
#   '4721',
#   '4926',
#   '4980',
#   '4957',
#   '5103',
#   '5253',
#   '5284',
#   '5314',
#   ''],
#  ['Panama',
#   '7597',
#   '7914',
#   '8495',
#   '8974',
#   '9155',
#   '8958',
#   '9184',
#   '9465',
#   '9929',
#   '9990',
#   '10226',
#   '10030',
#   '10396',
#   '10288',
#   '10707',
#   '11200',
#   '11967',
#   '13036',
#   '14170',
#   '14004',
#   '14182',
#   '16086',
#   '17235',
#   '17914',
#   '17985',
#   '18636',
#   '19212',
#   '20066',
#   '20455',
#   ''],
#  ['Papua New Guinea',
#   '2133',
#   '2296',
#   '2400',
#   '2784',
#   '2924',
#   '2809',
#   '2854',
#   '2746',
#   '2566',
#   '2519',
#   '2453',
#   '2350',
#   '2313',
#   '2216',
#   '2283',
#   '2439',
#   '2366',
#   '2627',
#   '2612',
#   '2728',
#   '2854',
#   '2881',
#   '2947',
#   '2833',
#   '3469',
#   '3739',
#   '3810',
#   '3765',
#   '3686',
#   ''],
#  ['Paraguay',
#   '6484',
#   '6408',
#   '6325',
#   '6829',
#   '7403',
#   '7827',
#   '8239',
#   '8120',
#   '7939',
#   '7649',
#   '7003',
#   '6902',
#   '6928',
#   '6537',
#   '6847',
#   '6956',
#   '7459',
#   '8123',
#   '8635',
#   '8461',
#   '9275',
#   '9668',
#   '9406',
#   '10092',
#   '10477',
#   '10649',
#   '10922',
#   '11430',
#   '11720',
#   ''],
#  ['Peru',
#   '4963',
#   '5113',
#   '4989',
#   '5112',
#   '5655',
#   '5940',
#   '6069',
#   '6363',
#   '6289',
#   '6280',
#   '6327',
#   '6322',
#   '6560',
#   '6703',
#   '6845',
#   '7127',
#   '7419',
#   '8007',
#   '8762',
#   '8847',
#   '9360',
#   '9842',
#   '10497',
#   '11163',
#   '11392',
#   '11760',
#   '11956',
#   '11987',
#   '12323',
#   ''],
#  ['Philippines',
#   '3965',
#   '3892',
#   '3869',
#   '3879',
#   '4001',
#   '4102',
#   '4275',
#   '4468',
#   '4695',
#   '4718',
#   '4972',
#   '5042',
#   '5143',
#   '5269',
#   '5493',
#   '5674',
#   '5822',
#   '6058',
#   '6222',
#   '6407',
#   '6737',
#   '6816',
#   '7179',
#   '7637',
#   '7947',
#   '8290',
#   '8701',
#   '9133',
#   '9540',
#   ''],
#  ['Poland',
#   '9946',
#   '9200',
#   '9314',
#   '9698',
#   '10480',
#   '11137',
#   '11891',
#   '12647',
#   '13230',
#   '13857',
#   '14667',
#   '14869',
#   '15178',
#   '15631',
#   '16078',
#   '16891',
#   '17880',
#   '18903',
#   '20031',
#   '20315',
#   '20986',
#   '22025',
#   '22356',
#   '22766',
#   '23447',
#   '24369',
#   '25042',
#   '26182',
#   '27626',
#   ''],
#  ['Portugal',
#   '20109',
#   '21079',
#   '21421',
#   '20976',
#   '21062',
#   '22018',
#   '22608',
#   '23334',
#   '24291',
#   '25095',
#   '25510',
#   '25795',
#   '25913',
#   '25701',
#   '26041',
#   '26182',
#   '26102',
#   '26694',
#   '26526',
#   '25753',
#   '26318',
#   '26264',
#   '25180',
#   '25305',
#   '25572',
#   '25860',
#   '26559',
#   '27404',
#   '27935',
#   ''],
#  ['Qatar',
#   '73168',
#   '70251',
#   '76947',
#   '75006',
#   '75236',
#   '76081',
#   '78027',
#   '99021',
#   '103043',
#   '103712',
#   '100344',
#   '104649',
#   '106944',
#   '107396',
#   '111551',
#   '99214',
#   '111972',
#   '110766',
#   '109401',
#   '103834',
#   '109354',
#   '114214',
#   '112528',
#   '112039',
#   '111753',
#   '114105',
#   '113965',
#   '113133',
#   '110489',
#   ' b'],
#  ['Romania',
#   '11434',
#   '10077',
#   '9246',
#   '9384',
#   '9775',
#   '10385',
#   '10805',
#   '10302',
#   '10085',
#   '10058',
#   '10368',
#   '11071',
#   '11875',
#   '12083',
#   '13165',
#   '14032',
#   '15171',
#   '16494',
#   '18478',
#   '17801',
#   '17207',
#   '17608',
#   '18044',
#   '18654',
#   '19558',
#   '20157',
#   '21173',
#   '22828',
#   '75906',
#   ''],
#  ['Russian Federation',
#   '20898',
#   '19782',
#   '16756',
#   '15338',
#   '13507',
#   '12897',
#   '12363',
#   '12471',
#   '11592',
#   '12417',
#   '13855',
#   '14823',
#   '15516',
#   '16532',
#   '17938',
#   '19086',
#   '20592',
#   '22542',
#   '23557',
#   '21688',
#   '22647',
#   '23594',
#   '24388',
#   '24675',
#   '24465',
#   '24032',
#   '24096',
#   '24472',
#   '25036',
#   ''],
#  ['Rwanda',
#   '865',
#   '866',
#   '970',
#   '952',
#   '501',
#   '694',
#   '750',
#   '801',
#   '803',
#   '779',
#   '796',
#   '829',
#   '918',
#   '920',
#   '975',
#   '1052',
#   '1125',
#   '1187',
#   '1282',
#   '1326',
#   '1386',
#   '1455',
#   '1538',
#   '1564',
#   '1634',
#   '1731',
#   '1785',
#   '1849',
#   '1959',
#   ''],
#  ['Saint Kitts and Nevis',
#   '15163',
#   '14666',
#   '14979',
#   '15811',
#   '16475',
#   '17337',
#   '17956',
#   '18899',
#   '18373',
#   '18717',
#   '20461',
#   '21260',
#   '21424',
#   '20126',
#   '21058',
#   '23149',
#   '23874',
#   '23803',
#   '25126',
#   '24043',
#   '23640',
#   '23898',
#   '23690',
#   '25084',
#   '24854',
#   '25298',
#   '25894',
#   '26287',
#   '26770',
#   ''],
#  ['Saint Lucia',
#   '8551',
#   '8445',
#   '9113',
#   '8954',
#   '9027',
#   '9013',
#   '9234',
#   '9024',
#   '9439',
#   '9609',
#   '9464',
#   '8912',
#   '9006',
#   '9219',
#   '9684',
#   '9561',
#   '11042',
#   '11059',
#   '11411',
#   '11343',
#   '11337',
#   '11881',
#   '11626',
#   '11502',
#   '10787',
#   '10480',
#   '11142',
#   '11599',
#   '11528',
#   ''],
#  ['Saint Vincent and the Grenadines',
#   '5321',
#   '5375',
#   '5797',
#   '6045',
#   '5913',
#   '6383',
#   '6530',
#   '6700',
#   '6977',
#   '7072',
#   '7197',
#   '7390',
#   '7844',
#   '8330',
#   '8595',
#   '8828',
#   '9625',
#   '9563',
#   '10222',
#   '10157',
#   '9832',
#   '9774',
#   '10036',
#   '9994',
#   '10535',
#   '11497',
#   '11337',
#   '11333',
#   '11746',
#   ''],
#  ['Samoa',
#   '4768',
#   '4574',
#   '4362',
#   '4561',
#   '2988',
#   '3103',
#   '3437',
#   '3438',
#   '3587',
#   '3628',
#   '3844',
#   '4113',
#   '4449',
#   '4606',
#   '4813',
#   '4942',
#   '5037',
#   '5348',
#   '5360',
#   '5142',
#   '5240',
#   '5459',
#   '5458',
#   '5303',
#   '5320',
#   '5456',
#   '5795',
#   '5876',
#   '5885',
#   ''],
#  ['Sao Tome and Principe',
#   '1816',
#   '1758',
#   '1732',
#   '1705',
#   '1716',
#   '1695',
#   '1721',
#   '1695',
#   '1684',
#   '1739',
#   '1738',
#   '1892',
#   '1906',
#   '2022',
#   '2049',
#   '2154',
#   '2389',
#   '2419',
#   '2468',
#   '2457',
#   '2567',
#   '2621',
#   '2590',
#   '2736',
#   '2883',
#   '2880',
#   '2962',
#   '3002',
#   '3024',
#   ''],
#  ['Saudi Arabia',
#   '44193',
#   '48313',
#   '48353',
#   '46788',
#   '45253',
#   '44744',
#   '44303',
#   '43906',
#   '44726',
#   '42345',
#   '43348',
#   '41866',
#   '39509',
#   '42567',
#   '44734',
#   '45970',
#   '46044',
#   '45861',
#   '47603',
#   '45276',
#   '45958',
#   '49173',
#   '50283',
#   '50244',
#   '50755',
#   '51509',
#   '51099',
#   '49371',
#   '49338',
#   ''],
#  ['Senegal',
#   '2262',
#   '2250',
#   '2233',
#   '2177',
#   '2117',
#   '2177',
#   '2194',
#   '2205',
#   '2289',
#   '2365',
#   '2381',
#   '2438',
#   '2388',
#   '2495',
#   '2582',
#   '2660',
#   '2663',
#   '2722',
#   '2764',
#   '2725',
#   '2749',
#   '2696',
#   '2754',
#   '2752',
#   '2846',
#   '2933',
#   '3018',
#   '3139',
#   '3256',
#   ''],
#  ['Serbia',
#   '12309',
#   '10777',
#   '7666',
#   '6802',
#   '6932',
#   '7309',
#   '7509',
#   '8107',
#   '8304',
#   '7298',
#   '7938',
#   '8353',
#   '8914',
#   '9307',
#   '10151',
#   '10714',
#   '11784',
#   '12506',
#   '13173',
#   '13006',
#   '13083',
#   '13453',
#   '13282',
#   '13634',
#   '13488',
#   '13677',
#   '14078',
#   '14280',
#   '15218',
#   ''],
#  ['Seychelles',
#   '13709',
#   '14000',
#   '15048',
#   '15627',
#   '15326',
#   '14514',
#   '15143',
#   '16896',
#   '17728',
#   '17609',
#   '17504',
#   '17513',
#   '15963',
#   '15810',
#   '16601',
#   '18002',
#   '19281',
#   '19508',
#   '18353',
#   '18468',
#   '19226',
#   '20991',
#   '21340',
#   '22225',
#   '22638',
#   '23355',
#   '23671',
#   '24431',
#   '25077',
#   ''],
#  ['Sierra Leone',
#   '1114',
#   '1171',
#   '915',
#   '987',
#   '903',
#   '893',
#   '931',
#   '885',
#   '862',
#   '843',
#   '880',
#   '800',
#   '970',
#   '1017',
#   '1035',
#   '1040',
#   '1053',
#   '1184',
#   '1251',
#   '1275',
#   '1222',
#   '1238',
#   '1460',
#   '1661',
#   '1673',
#   '1309',
#   '1228',
#   '1360',
#   '1381',
#   ''],
#  ['Singapore',
#   '34576',
#   '35663',
#   '37500',
#   '39878',
#   '43910',
#   '45938',
#   '46719',
#   '50261',
#   '47286',
#   '49422',
#   '52046',
#   '50091',
#   '50856',
#   '53580',
#   '55941',
#   '58890',
#   '64304',
#   '67296',
#   '64409',
#   '61565',
#   '72280',
#   '73422',
#   '74094',
#   '75742',
#   '79236',
#   '77686',
#   '78759',
#   '81500',
#   '83793',
#   ' b'],
#  ['Slovakia',
#   '14628',
#   '12404',
#   '11544',
#   '11664',
#   '12358',
#   '13245',
#   '14149',
#   '14876',
#   '15443',
#   '15298',
#   '15513',
#   '16150',
#   '16813',
#   '16874',
#   '17965',
#   '19433',
#   '21030',
#   '23310',
#   '24896',
#   '23801',
#   '24585',
#   '24896',
#   '25716',
#   '26328',
#   '26939',
#   '27693',
#   '28706',
#   '29544',
#   '30672',
#   ''],
#  ['Slovenia',
#   '83449',
#   '48846',
#   '16414',
#   '13956',
#   '13684',
#   '18515',
#   '19133',
#   '20076',
#   '20759',
#   '21853',
#   '22656',
#   '23325',
#   '23999',
#   '24618',
#   '25587',
#   '26695',
#   '28026',
#   '29483',
#   '30313',
#   '27963',
#   '28291',
#   '28411',
#   '27545',
#   '27253',
#   '28149',
#   '28128',
#   '29114',
#   '30777',
#   '32143',
#   ''],
#  ['Solomon Islands',
#   '1291',
#   '1396',
#   '1452',
#   '1335',
#   '1422',
#   '1482',
#   '1420',
#   '2241',
#   '2214',
#   '2151',
#   '1818',
#   '1637',
#   '1531',
#   '1593',
#   '1650',
#   '1687',
#   '1772',
#   '1711',
#   '1630',
#   '1300',
#   '1364',
#   '1489',
#   '1840',
#   '1961',
#   '1967',
#   '2033',
#   '1986',
#   '1970',
#   '2027',
#   ''],
#  ['South Africa',
#   '9588',
#   '9349',
#   '8951',
#   '8855',
#   '8951',
#   '9023',
#   '9210',
#   '9286',
#   '9167',
#   '9244',
#   '9498',
#   '9556',
#   '9842',
#   '9985',
#   '10388',
#   '10798',
#   '11257',
#   '11545',
#   '11777',
#   '11535',
#   '11723',
#   '11868',
#   '11923',
#   '12038',
#   '12063',
#   '12052',
#   '11908',
#   '11864',
#   '11756',
#   ''],
#  ['South Sudan',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   '2399',
#   '2403',
#   '2421',
#   '2381',
#   '2234',
#   '2372',
#   '2310',
#   '2096',
#   '1686',
#   '1518',
#   '1455',
#   ' d'],
#  ['Spain',
#   '23594',
#   '24144',
#   '24217',
#   '23975',
#   '23991',
#   '24982',
#   '25463',
#   '26307',
#   '27308',
#   '28422',
#   '29853',
#   '30624',
#   '31044',
#   '31554',
#   '31961',
#   '32422',
#   '33110',
#   '33494',
#   '33248',
#   '32044',
#   '32045',
#   '31512',
#   '30888',
#   '30516',
#   '31088',
#   '32265',
#   '33379',
#   '34226',
#   '35041',
#   ''],
#  ['Sri Lanka',
#   '3587',
#   '3704',
#   '3845',
#   '4076',
#   '4239',
#   '4408',
#   '4540',
#   '4815',
#   '4993',
#   '5168',
#   '5441',
#   '5323',
#   '5505',
#   '5816',
#   '6077',
#   '6391',
#   '6820',
#   '7250',
#   '7537',
#   '7835',
#   '8409',
#   '9064',
#   '9804',
#   '9996',
#   '10399',
#   '10789',
#   '11124',
#   '11378',
#   '11611',
#   ''],
#  ['Sudan',
#   '1614',
#   '1576',
#   '1689',
#   '1769',
#   '1781',
#   '1855',
#   '1967',
#   '2139',
#   '2164',
#   '2147',
#   '2178',
#   '2233',
#   '2325',
#   '2404',
#   '2412',
#   '2549',
#   '2757',
#   '2967',
#   '3118',
#   '3130',
#   '3128',
#   '3494',
#   '3758',
#   '2685',
#   '3772',
#   '3904',
#   '3994',
#   '4092',
#   '3962',
#   ''],
#  ['Suriname',
#   '10377',
#   '10448',
#   '10322',
#   '9321',
#   '9562',
#   '9463',
#   '9380',
#   '9585',
#   '9713',
#   '9311',
#   '9305',
#   '8804',
#   '9847',
#   '10356',
#   '11058',
#   '11656',
#   '12219',
#   '12952',
#   '13423',
#   '13608',
#   '13793',
#   '13912',
#   '14435',
#   '14896',
#   '14955',
#   '14448',
#   '12792',
#   '11607',
#   '11933',
#   ''],
#  ['Sweden',
#   '30334',
#   '29502',
#   '28487',
#   '27527',
#   '29069',
#   '30122',
#   '30587',
#   '31489',
#   '33132',
#   '35231',
#   '36928',
#   '37414',
#   '38148',
#   '39454',
#   '40532',
#   '41836',
#   '44087',
#   '45438',
#   '45030',
#   '41885',
#   '44175',
#   '44717',
#   '44360',
#   '44514',
#   '45157',
#   '46168',
#   '46662',
#   '47398',
#   '47955',
#   ''],
#  ['Switzerland',
#   '49156',
#   '48156',
#   '47492',
#   '47218',
#   '47077',
#   '47382',
#   '47545',
#   '49353',
#   '50883',
#   '51880',
#   '54127',
#   '53135',
#   '52175',
#   '53812',
#   '54719',
#   '57194',
#   '58584',
#   '56611',
#   '53101',
#   '55849',
#   '59150',
#   '56832',
#   '57403',
#   '57718',
#   '57463',
#   '58723',
#   '58138',
#   '57301',
#   '59375',
#   ''],
#  ['Syrian Arab Republic',
#   '3432',
#   '3589',
#   '3975',
#   '4075',
#   '4426',
#   '4608',
#   '4815',
#   '5027',
#   '5111',
#   '4814',
#   '4664',
#   '4764',
#   '5039',
#   '4997',
#   '5246',
#   '5379',
#   '5562',
#   '5725',
#   '5754',
#   '5964',
#   '6086',
#   '5752',
#   '4567',
#   '3538',
#   '2830',
#   '2658',
#   '2551',
#   '2633',
#   '2725',
#   ' e'],
#  ['Tajikistan',
#   '4147',
#   '3770',
#   '2627',
#   '2161',
#   '1348',
#   '1386',
#   '1104',
#   '1153',
#   '1203',
#   '1228',
#   '1286',
#   '1390',
#   '1515',
#   '1637',
#   '1810',
#   '1905',
#   '1998',
#   '2135',
#   '2273',
#   '2306',
#   '2704',
#   '2863',
#   '3006',
#   '3190',
#   '3133',
#   '3089',
#   '3168',
#   '3262',
#   '3482',
#   ''],
#  ['Tanzania (United Republic of)',
#   '1490',
#   '1478',
#   '1434',
#   '1407',
#   '1389',
#   '1407',
#   '1449',
#   '1457',
#   '1485',
#   '1521',
#   '1549',
#   '1579',
#   '1673',
#   '1725',
#   '1802',
#   '1872',
#   '1974',
#   '2025',
#   '2085',
#   '2134',
#   '2187',
#   '2286',
#   '2328',
#   '2410',
#   '2494',
#   '2562',
#   '2648',
#   '2743',
#   '2805',
#   ''],
#  ['Thailand',
#   '6562',
#   '7023',
#   '7452',
#   '8039',
#   '8592',
#   '9180',
#   '9530',
#   '9117',
#   '8244',
#   '8608',
#   '9004',
#   '9155',
#   '9564',
#   '10114',
#   '10647',
#   '11008',
#   '11576',
#   '12176',
#   '12297',
#   '12164',
#   '12921',
#   '13211',
#   '13797',
#   '13840',
#   '14101',
#   '14466',
#   '14966',
#   '15548',
#   '16129',
#   ''],
#  ['Timor-Leste',
#   '4069',
#   '4362',
#   '4684',
#   '5021',
#   '5185',
#   '5669',
#   '6302',
#   '6872',
#   '6791',
#   '3371',
#   '4993',
#   '5262',
#   '5668',
#   '4735',
#   '3385',
#   '1818',
#   '3199',
#   '6646',
#   '7176',
#   '8220',
#   '8155',
#   '7974',
#   '4717',
#   '6233',
#   '5666',
#   '8284',
#   '8350',
#   '7434',
#   '7527',
#   ''],
#  ['Togo',
#   '1302',
#   '1262',
#   '1189',
#   '987',
#   '1082',
#   '1155',
#   '1236',
#   '1371',
#   '1300',
#   '1280',
#   '1236',
#   '1182',
#   '1148',
#   '1176',
#   '1168',
#   '1153',
#   '1169',
#   '1164',
#   '1189',
#   '1220',
#   '1259',
#   '1364',
#   '1361',
#   '1413',
#   '1463',
#   '1539',
#   '1545',
#   '1560',
#   '1593',
#   ''],
#  ['Tonga',
#   '3670',
#   '3866',
#   '3845',
#   '3969',
#   '4314',
#   '4346',
#   '4353',
#   '4336',
#   '4513',
#   '4546',
#   '4589',
#   '4718',
#   '4975',
#   '5004',
#   '4974',
#   '4952',
#   '4960',
#   '4742',
#   '4834',
#   '4971',
#   '5153',
#   '5298',
#   '5393',
#   '5252',
#   '5306',
#   '5534',
#   '5678',
#   '5836',
#   '5783',
#   ''],
#  ['Trinidad and Tobago',
#   '10058',
#   '10247',
#   '11224',
#   '11239',
#   '11416',
#   '11937',
#   '12534',
#   '13789',
#   '15046',
#   '16186',
#   '16923',
#   '17870',
#   '19364',
#   '21889',
#   '24267',
#   '25126',
#   '28240',
#   '29676',
#   '30565',
#   '28806',
#   '29737',
#   '27546',
#   '28402',
#   '29770',
#   '29142',
#   '31160',
#   '28854',
#   '28786',
#   '28497',
#   ''],
#  ['Tunisia',
#   '5462',
#   '5505',
#   '5784',
#   '5707',
#   '5810',
#   '5891',
#   '6182',
#   '6487',
#   '6739',
#   '7073',
#   '7309',
#   '7533',
#   '7573',
#   '7889',
#   '8303',
#   '8438',
#   '8829',
#   '9248',
#   '9486',
#   '9740',
#   '9977',
#   '9661',
#   '9991',
#   '10126',
#   '10419',
#   '10484',
#   '10531',
#   '10564',
#   '10677',
#   ''],
#  ['Turkey',
#   '11214',
#   '11099',
#   '11482',
#   '12174',
#   '11317',
#   '12089',
#   '12804',
#   '13562',
#   '13719',
#   '13010',
#   '13656',
#   '12518',
#   '13208',
#   '13766',
#   '14945',
#   '16129',
#   '17062',
#   '17734',
#   '17662',
#   '16584',
#   '17804',
#   '19481',
#   '20106',
#   '21414',
#   '22146',
#   '23048',
#   '23409',
#   '24702',
#   '24905',
#   ''],
#  ['Turkmenistan',
#   '8375',
#   '7768',
#   '6418',
#   '6334',
#   '5251',
#   '4635',
#   '4853',
#   '4347',
#   '4497',
#   '5102',
#   '5008',
#   '5343',
#   '5316',
#   '5516',
#   '5718',
#   '6044',
#   '6691',
#   '7590',
#   '8369',
#   '8674',
#   '9109',
#   '10128',
#   '11077',
#   '12083',
#   '13041',
#   '14115',
#   '15236',
#   '15710',
#   '16407',
#   ''],
#  ['Tuvalu',
#   '4713',
#   '4866',
#   '5066',
#   '4740',
#   '5477',
#   '5241',
#   '4687',
#   '5505',
#   '5922',
#   '5670',
#   '4889',
#   '5811',
#   '7063',
#   '4817',
#   '5161',
#   '4940',
#   '4809',
#   '5463',
#   '5333',
#   '5423',
#   '4779',
#   '4743',
#   '3971',
#   '4845',
#   '4186',
#   '5315',
#   '5239',
#   '5075',
#   '5409',
#   ''],
#  ['Uganda',
#   '758',
#   '775',
#   '765',
#   '814',
#   '839',
#   '912',
#   '968',
#   '994',
#   '1014',
#   '1063',
#   '1048',
#   '1055',
#   '1122',
#   '1159',
#   '1191',
#   '1224',
#   '1320',
#   '1394',
#   '1471',
#   '1523',
#   '1559',
#   '1654',
#   '1656',
#   '1658',
#   '1684',
#   '1717',
#   '1733',
#   '1727',
#   '1752',
#   ''],
#  ['Ukraine',
#   '10744',
#   '9801',
#   '8609',
#   '7216',
#   '5689',
#   '4993',
#   '4548',
#   '4451',
#   '4374',
#   '4371',
#   '4665',
#   '5210',
#   '5555',
#   '6149',
#   '6940',
#   '7207',
#   '7759',
#   '8400',
#   '8694',
#   '7359',
#   '7715',
#   '8089',
#   '8179',
#   '8194',
#   '8145',
#   '7373',
#   '7601',
#   '7670',
#   '7994',
#   ''],
#  ['United Arab Emirates',
#   '110756',
#   '104110',
#   '100694',
#   '100178',
#   '103248',
#   '106644',
#   '106927',
#   '108850',
#   '103821',
#   '101107',
#   '108412',
#   '104337',
#   '97501',
#   '98534',
#   '99013',
#   '93174',
#   '89202',
#   '80087',
#   '70366',
#   '59484',
#   '55342',
#   '56592',
#   '57900',
#   '60675',
#   '63062',
#   '66093',
#   '67410',
#   '67136',
#   '66912',
#   ''],
#  ['United Kingdom',
#   '26485',
#   '26133',
#   '26228',
#   '26800',
#   '27864',
#   '28410',
#   '29072',
#   '30283',
#   '31365',
#   '32056',
#   '33278',
#   '34209',
#   '35116',
#   '36116',
#   '36670',
#   '37682',
#   '37882',
#   '38325',
#   '37721',
#   '35907',
#   '36534',
#   '36966',
#   '36707',
#   '36825',
#   '37627',
#   '38116',
#   '38421',
#   '39216',
#   '39507',
#   ''],
#  ['United States',
#   '37154',
#   '36597',
#   '37350',
#   '37867',
#   '38858',
#   '39449',
#   '40470',
#   '41718',
#   '43049',
#   '44612',
#   '45974',
#   '46032',
#   '46379',
#   '47343',
#   '48752',
#   '49980',
#   '50795',
#   '51457',
#   '51048',
#   '49292',
#   '50297',
#   '50813',
#   '51533',
#   '52092',
#   '52982',
#   '54039',
#   '54443',
#   '55351',
#   '56140',
#   ''],
#  ['Uruguay',
#   '9499',
#   '9892',
#   '10656',
#   '10876',
#   '11553',
#   '11336',
#   '11907',
#   '12923',
#   '13417',
#   '13177',
#   '12864',
#   '12344',
#   '11493',
#   '11044',
#   '11576',
#   '12638',
#   '13231',
#   '14070',
#   '14919',
#   '15455',
#   '16521',
#   '17382',
#   '17192',
#   '18306',
#   '18632',
#   '19036',
#   '19196',
#   '19400',
#   '19435',
#   ''],
#  ['Uzbekistan',
#   '3089',
#   '3002',
#   '2604',
#   '2492',
#   '2317',
#   '2257',
#   '2246',
#   '2303',
#   '2376',
#   '2444',
#   '2487',
#   '2553',
#   '2630',
#   '2719',
#   '2910',
#   '3084',
#   '3262',
#   '3685',
#   '4005',
#   '4134',
#   '4373',
#   '4645',
#   '4980',
#   '5351',
#   '5573',
#   '5759',
#   '5968',
#   '6190',
#   '6462',
#   ''],
#  ['Vanuatu',
#   '2619',
#   '2339',
#   '2269',
#   '2402',
#   '2304',
#   '2421',
#   '2358',
#   '2402',
#   '2675',
#   '2670',
#   '2690',
#   '2624',
#   '2360',
#   '2388',
#   '2413',
#   '2441',
#   '2639',
#   '2692',
#   '2955',
#   '2888',
#   '2846',
#   '2820',
#   '2700',
#   '2835',
#   '2840',
#   '2680',
#   '2751',
#   '2799',
#   '2808',
#   ''],
#  ['Venezuela (Bolivarian Republic of)',
#   '14529',
#   '15667',
#   '15945',
#   '15666',
#   '14919',
#   '15290',
#   '14943',
#   '15524',
#   '15322',
#   '14286',
#   '14562',
#   '14715',
#   '12974',
#   '11790',
#   '13592',
#   '15010',
#   '16443',
#   '18014',
#   '18486',
#   '17417',
#   '16783',
#   '16882',
#   '17532',
#   '17459',
#   '17111',
#   '15101',
#   '12570',
#   '10670',
#   '9070',
#   ' g'],
#  ['Viet Nam',
#   '1369',
#   '1436',
#   '1559',
#   '1645',
#   '1781',
#   '1944',
#   '2084',
#   '2217',
#   '2315',
#   '2408',
#   '2725',
#   '2868',
#   '3020',
#   '3190',
#   '3416',
#   '3367',
#   '3557',
#   '3752',
#   '3918',
#   '3705',
#   '4266',
#   '4461',
#   '4655',
#   '4843',
#   '5052',
#   '5314',
#   '5638',
#   '5916',
#   '6220',
#   ''],
#  ['Yemen',
#   '2382',
#   '2423',
#   '2258',
#   '2237',
#   '2112',
#   '1796',
#   '2364',
#   '2760',
#   '3447',
#   '2579',
#   '2748',
#   '3431',
#   '3366',
#   '3375',
#   '3386',
#   '3141',
#   '3279',
#   '3703',
#   '3575',
#   '4490',
#   '3688',
#   '3876',
#   '3365',
#   '3351',
#   '3296',
#   '2668',
#   '1966',
#   '1508',
#   '1433',
#   ' e'],
#  ['Zambia',
#   '2140',
#   '2020',
#   '1969',
#   '2101',
#   '1900',
#   '1909',
#   '1988',
#   '2006',
#   '1935',
#   '2001',
#   '2034',
#   '2094',
#   '2142',
#   '2248',
#   '2261',
#   '2332',
#   '2409',
#   '2490',
#   '2705',
#   '3031',
#   '3114',
#   '3251',
#   '3520',
#   '3482',
#   '3615',
#   '3617',
#   '3622',
#   '3553',
#   '3582',
#   ''],
#  ['Zimbabwe',
#   '2693',
#   '2764',
#   '2448',
#   '2440',
#   '2611',
#   '2574',
#   '2833',
#   '2851',
#   '2871',
#   '2854',
#   '2747',
#   '2792',
#   '2554',
#   '2124',
#   '1973',
#   '1853',
#   '1759',
#   '1662',
#   '1308',
#   '1399',
#   '1689',
#   '1861',
#   '2158',
#   '2239',
#   '2259',
#   '2226',
#   '2246',
#   '2318',
#   '2661',
#   '']]

# %%
secondData = loadList ('ghi_data_csv.csv')

# %%
'''dataSet = []
for i in range (0,len(rawData)):
    dataSet += [[i][1],[i][2]]
    
dataSet'''
#Second B4 file
#Author: Bill Han
#Date: October 2021

import library #This imports the library
#This is my second CSV file

#Country,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,
#2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,Info

incomeCol = {"income": 29, "country": 0}
hungerCol = {"poverty": 2, "country": 0}
#These are the columns for income and country and poverty and country respectively

incomeInfo = library.loadList("Book1.csv") #Importing the first CSV file
hungerInfo = library.loadList("ghi_data_csv.csv") #Importing the second CSV file

c = 0
mylist = []
#Variable name

for i in range(0, len(incomeInfo)):
    income = incomeInfo[i][incomeCol["income"]]
    hunger = hungerInfo[i][hungerCol ["poverty"]]
    hungerCode = incomeInfo[i][incomeCol["country"]]
    #Defining each variable
    if income != '' and hunger!= '':
        ratio = float (income)/ float (hunger)
        
    c = 0
    
    while c < len(hungerInfo) and hungerInfo[c][hungerCol["country"]].lower() == hungerCode.lower():
        
        c += 1
        if c < len(hungerInfo):
            country = hungerInfo[c][hungerCol["country"]]
            
        else:
            country = "Unknown"
    
    newratio = round (ratio, 1) 
    
    
    #This rounds the ratio to the nearest tenth because there would have been 20ish numbers after the decimal
    if hunger: 
        mylist.append([country, int(income), float(hunger), float(newratio)])
    #Puts the strings and integers into a list (The country is a string while the other variables are integers)


#Print Command
for c in mylist:
    print (c)
# Out:
# ['Angola', 1746, 34.8, 50.2]
# ['Angola', 12300, 32.8, 375.0]
# ['Angola', 13639, 11.9, 1146.1]
# ['Angola', 5555, 23.2, 239.4]
# ['Angola', 22201, 31.0, 716.2]
# ['Angola', 77611, 27.1, 2863.9]
# ['Angola', 9277, 18.3, 506.9]
# ['Angola', 46231, 5.0, 9246.2]
# ['Angola', 15240, 22.3, 683.4]
# ['Angola', 28395, 15.4, 1843.8]
# ['Angola', 40399, 20.0, 2020.0]
# ['Angola', 15912, 23.0, 691.8]
# ['Angola', 17039, 46.1, 369.6]
# ['Angola', 43821, 25.7, 1705.1]
# ['Angola', 7136, 22.9, 311.6]
# ['Angola', 8609, 26.6, 323.6]
# ['Angola', 6849, 8.5, 805.8]
# ['Angola', 15951, 32.7, 487.8]
# ['Angola', 14068, 11.1, 1267.4]
# ['Angola', 76389, 28.7, 2661.6]
# ['Angola', 19646, 13.9, 1413.4]
# ['Angola', 1705, 13.7, 124.5]
# ['Angola', 6513, 45.0, 144.7]
# ['Angola', 3597, 33.4, 107.7]
# ['Angola', 3291, 48.5, 67.9]
# ['Angola', 43602, 12.0, 3633.5]
# ['Angola', 777, 48.2, 16.1]
# ['Angola', 1716, 13.9, 123.5]
# ['Angola', 21972, 28.1, 781.9]
# ['Angola', 16127, 20.9, 771.6]
# ['Angola', 12896, 27.4, 470.7]
# ['Angola', 2426, 20.7, 117.2]
# ['Angola', 5804, 34.5, 168.2]
# ['Angola', 800, 13.2, 60.6]
# ['Angola', 14790, 45.0, 328.7]
# ['Angola', 23061, 36.9, 625.0]
# ['Angola', 7811, 21.9, 356.7]
# ['Angola', 33100, 28.5, 1161.4]
# ['Angola', 31597, 21.9, 1442.8]
# ['Angola', 3589, 59.1, 60.7]
# ['Angola', 48836, 21.7, 2250.5]
# ['Angola', 3601, 59.0, 61.0]
# ['Angola', 9245, 28.1, 329.0]
# ['Angola', 15074, 7.1, 2123.1]
# ['Angola', 10141, 30.7, 330.3]
# ['Angola', 6973, 25.5, 273.5]
# ['Angola', 17796, 22.7, 784.0]
# ['Angola', 1708, 35.4, 48.2]
# ['Angola', 30379, 7.2, 4219.3]
# ['Angola', 9359, 5.8, 1613.6]
# ['Angola', 1782, 28.1, 63.4]
# ['Angola', 79110, 22.0, 3595.9]
# ['Angola', 41779, 5.0, 8355.8]
# ['Angola', 40511, 13.8, 2935.6]
# ['Angola', 15794, 31.7, 498.2]
# ['Angola', 1490, 22.1, 67.4]
# ['Angola', 9570, 13.2, 725.0]
# ['Angola', 46946, 26.9, 1745.2]
# ['Angola', 4099, 9.7, 422.6]
# ['Angola', 24909, 31.4, 793.3]
# ['Angola', 12684, 33.7, 376.4]
# ['Angola', 7378, 25.5, 289.3]
# ['Angola', 2211, 13.3, 166.2]
# ['Angola', 1593, 21.9, 72.7]
# ['Angola', 7615, 10.4, 732.2]
# ['Angola', 1665, 33.4, 49.9]
# ['Angola', 4258, 9.3, 457.8]
# ['Angola', 60221, 8.6, 7002.4]
# ['Angola', 27144, 19.9, 1364.0]
# ['Angola', 6829, 28.6, 238.8]
# ['Angola', 11256, 10.4, 1082.3]
# ['Angola', 15365, 5.5, 2793.6]
# ['Angola', 55660, 6.8, 8185.3]
# ['Angola', 33650, 27.4, 1228.1]
# ['Angola', 36141, 5.0, 7228.2]
# ['Angola', 40799, 16.5, 2472.7]
# ['Angola', 8268, 35.0, 236.2]
# ['Angola', 22168, 11.2, 1979.3]
# ['Angola', 3917, 7.1, 551.7]
# ['Angola', 71164, 10.1, 7045.9]
# ['Angola', 3317, 5.3, 625.8]
# ['Angola', 6317, 24.2, 261.0]
# ['Angola', 11136, 44.3, 251.4]
# ['Angola', 3244, 22.4, 144.8]
# ['Angola', 1040, 11.8, 88.1]
# ['Angola', 11685, 30.0, 389.5]
# ['Angola', 99732, 12.3, 8108.3]
# ['Angola', 29775, 34.3, 868.1]
# ['Angola', 65543, 8.5, 7710.9]
# ['Angola', 1404, 5.5, 255.3]
# ['Angola', 1159, 5.0, 231.8]
# ['Angola', 27227, 28.4, 958.7]
# ['Angola', 12549, 26.4, 475.3]
# ['Angola', 1965, 5.0, 393.0]
# ['Angola', 34795, 5.6, 6213.4]
# ['Angola', 4633, 13.1, 353.7]
# ['Angola', 3746, 7.0, 535.1]
# ['Angola', 22724, 64.5, 352.3]
# ['Angola', 17628, 35.0, 503.7]
# ['Angola', 3700, 11.8, 313.6]
# ['Angola', 6833, 39.0, 175.2]
# ['Angola', 10784, 28.8, 374.4]
# ['Angola', 17511, 49.3, 355.2]
# ['Angola', 7480, 65.9, 113.5]
# ['Angola', 1154, 20.4, 56.6]
# ['Angola', 5764, 5.8, 993.8]
# ['Angola', 50013, 44.6, 1121.4]
# ['Angola', 35108, 47.7, 736.0]
# ['Angola', 4790, 52.4, 91.4]
# ['Angola', 912, 9.3, 98.1]
# ['Angola', 37039, 36.7, 1009.2]
# ['Angola', 5190, 16.1, 322.4]
# ['Angola', 5314, 32.4, 164.0]
# ['Angola', 20455, 52.2, 391.9]
# ['Angola', 3686, 6.2, 594.5]
# ['Angola', 11720, 26.4, 443.9]
# ['Angola', 12323, 31.8, 387.5]
# ['Angola', 9540, 40.4, 236.1]
# ['Angola', 27935, 37.6, 743.0]
# ['Angola', 110489, 15.1, 7317.2]
# ['Angola', 25036, 7.6, 3294.2]
# ['Angola', 1959, 8.7, 225.2]
# ['Angola', 26770, 61.1, 438.1]
# ['Angola', 11528, 25.0, 461.1]
# ['Angola', 11746, 16.8, 699.2]
# ['Angola', 5885, 23.6, 249.4]
# ['Angola', 3024, 19.3, 156.7]
# ['Angola', 15218, 70.9, 214.6]
# ['Angola', 25077, 11.7, 2143.3]
# ['Angola', 1381, 21.1, 65.5]
# ['Angola', 30672, 42.7, 718.3]
# ['Angola', 32143, 46.1, 697.2]
# ['Angola', 2027, 33.5, 60.5]
# ['Angola', 11756, 45.2, 260.1]
# ['Angola', 1455, 28.4, 51.2]
# ['Angola', 35041, 24.1, 1454.0]
# ['Angola', 11611, 25.8, 450.0]
# ['Angola', 11933, 51.6, 231.3]
# ['Angola', 47955, 35.8, 1339.5]
# ['Angola', 59375, 46.4, 1279.6]
# ['Angola', 2725, 17.5, 155.7]
# ['Angola', 3482, 19.6, 177.7]
# ['Angola', 2805, 12.4, 226.2]
# ['Angola', 16129, 12.6, 1280.1]
# ['Angola', 1593, 38.5, 41.4]
# ['Angola', 28497, 45.3, 629.1]
# ['Angola', 10677, 26.0, 410.7]
# ['Angola', 24905, 52.2, 477.1]
# ['Angola', 16407, 11.4, 1439.2]
# ['Angola', 5409, 49.7, 108.8]
# ['Angola', 7994, 31.8, 251.4]
# ['Angola', 66912, 25.9, 2583.5]
# ['Angola', 19435, 18.3, 1062.0]
# ['Angola', 2808, 44.6, 63.0]
# ['Angola', 9070, 14.6, 621.2]
# ['Angola', 1433, 50.2, 28.5]
# ['Angola', 3582, 55.8, 64.2]

# %%
dataFrame = pd.DataFrame(mylist, columns = ['Country', 'AverageIncome', 'HungerIndex', 'Ratio'])
dataFrame
# Out:
#     Country  AverageIncome  HungerIndex   Ratio
# 0    Angola           1746         34.8    50.2
# 1    Angola          12300         32.8   375.0
# 2    Angola          13639         11.9  1146.1
# 3    Angola           5555         23.2   239.4
# 4    Angola          22201         31.0   716.2
# ..      ...            ...          ...     ...
# 152  Angola          19435         18.3  1062.0
# 153  Angola           2808         44.6    63.0
# 154  Angola           9070         14.6   621.2
# 155  Angola           1433         50.2    28.5
# 156  Angola           3582         55.8    64.2
#
# [157 rows x 4 columns]

# %%
x = dataFrame.AverageIncome



y = dataFrame.HungerIndex
p = list(x)
for i in range (len(p)):
    p[i] /= 10
labels = list(dataFrame.Country)
plt.figure(figsize=(30,15))
plt.title ('Average Income v.s. Hunger Index', fontsize = 40)
#axes = plt.gca()
#axes.yaxis.label.set_size(2)
#axes.xaxis.label.set_size(2)
matplotlib.pyplot.xticks(fontsize=20)
matplotlib.pyplot.yticks(fontsize=20)
plt.xlabel('Average Income (USD)', fontsize = 30)
plt.ylabel('Hunger Index', fontsize = 30)
plt.scatter(x, y, s=p, c=p, label = "Countries")

z = np.polyfit(x, y, 2)

model = np.poly1d(np.polyfit(x, y, 2))

#add fitted polynomial line to scatterplot
polyline = np.linspace(1, 100000, 70)
#plt.plot(polyline, model(polyline))
#plt.show()

p = np.poly1d(z)
plt.legend(loc="upper right", prop={'size':40})
plt.plot(polyline, model(polyline))
plt.show()

# %%
fig = plt.figure()
ax = plt.axes()
plt.grid()
plt.show()

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
